# %% [markdown]
# ## Загружаем датасет в colab из Kaggle

# %% [markdown]
# Подробно расписано, как это делать: https://medium.com/@saedhussain/google-colaboratory-and-kaggle-datasets-b57a83eb6ef8

# %% [markdown]
# и здесь: https://www.kaggle.com/general/74235

# %%
# !ls
# Out:
# sample_data

# %%
# Colab library to upload files to notebook
from google.colab import files
import os

# %%
# Install Kaggle library
# !pip install -q kaggle

# %%
# Upload kaggle API key file (надо загрузить kaggle.json, который можно получить из своего профиля kaggle)
files.upload()
# Out:
#      <input type="file" id="files-7ee6726e-1e42-4288-b796-12589b65f5f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ee6726e-1e42-4288-b796-12589b65f5f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"dmitryfedorov1992","key":"7035c735f9ff36dac40780f2fdb80851"}'}

# %%
# !ls
# Out:
# kaggle.json  sample_data

# %%
# API key file надо обязательно закинуть в корневой каталог
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                         title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge           COVID-19 Open Research Dataset Challenge (CORD-19)    3GB  2020-06-29 17:04:40          84514
# roche-data-science-coalition/uncover                        UNCOVER COVID-19 Challenge                          179MB  2020-05-21 18:57:53          14566
# josehenriqueroveda/fertilizers-by-product-fao               Fertilizers by Product FAO                            1MB  2020-06-16 13:01:07            364
# madeleineferguson/farmers-markets-in-the-united-states      Farmers Markets in the United States                816KB  2020-06-10 16:41:46            633
# promptcloud/jobs-on-naukricom                               Jobs On Naukri.com                                    3MB  2020-06-15 10:51:07            693
# mikahama/the-best-sarcasm-annotated-dataset-in-spanish      The Best Sarcasm Annotated Dataset in Spanish        26KB  2020-06-21 16:50:44             65
# yeayates21/garage-detection-unofficial-ssl-challenge        Garage Detection Unofficial SSL Challenge            33MB  2020-06-18 14:00:08             54
# shubh0799/churn-modelling                                   Churn Modelling                                     262KB  2020-06-20 17:33:28            487
# jessemostipak/caribou-location-tracking                     Caribou Location Tracking                             6MB  2020-06-22 21:44:58            114
# rohan0301/unsupervised-learning-on-country-data             Unsupervised Learning on Country Data                 5KB  2020-06-17 07:45:45            534
# benroshan/factors-affecting-campus-placement                Campus Recruitment                                    5KB  2020-04-11 11:09:02           9715
# bobbyscience/league-of-legends-diamond-ranked-games-10-min  League of Legends Diamond Ranked Games (10 min)     539KB  2020-04-13 13:53:02           4041
# fireballbyedimyrnmom/us-counties-covid-19-dataset           US counties COVID 19 dataset                          3MB  2020-07-01 13:26:07           9248
# divyansh22/flight-delay-prediction                          January Flight Delay Prediction                      23MB  2020-04-14 13:15:41           3321
# clmentbisaillon/fake-and-real-news-dataset                  Fake and real news dataset                           41MB  2020-03-26 18:51:15           8327
# ikiulian/global-hospital-beds-capacity-for-covid19          Global Hospital Beds Capacity (for covid-19)        284KB  2020-04-26 09:39:35           2817
# praveengovi/coronahack-chest-xraydataset                    CoronaHack -Chest X-Ray-Dataset                       1GB  2020-03-20 01:26:40           4178
# bappekim/air-pollution-in-seoul                             Air Pollution in Seoul                               20MB  2020-04-03 16:33:49           4317
# kimjihoo/coronavirusdataset                                 Data Science for COVID-19 (DS4C)                      7MB  2020-07-01 06:11:23          45221
# sudalairajkumar/novel-corona-virus-2019-dataset             Novel Corona Virus 2019 Dataset                       2MB  2020-07-01 05:35:59         220446

# %%
# !kaggle datasets download -d jessicali9530/stanford-dogs-dataset -p 'stan_dog_dataset'
# Out:
# Downloading stanford-dogs-dataset.zip to stan_dog_dataset
#  98% 739M/750M [00:07<00:00, 121MB/s]
# 100% 750M/750M [00:07<00:00, 110MB/s]

# %%
# !ls
# Out:
# kaggle.json  sample_data  stan_dog_dataset

# %%
print(os.listdir("/content"))
# Out:
# ['.config', 'stan_dog_dataset', 'kaggle.json', 'sample_data']

# %%
print(os.listdir("/content/stan_dog_dataset"))
# Out:
# ['stanford-dogs-dataset.zip']

# %%
# !ls
# Out:
# kaggle.json  sample_data  stan_dog_dataset

# %%
os.chdir('stan_dog_dataset')

# %%
# !ls
# Out:
# stanford-dogs-dataset.zip

# %%
! mkdir dataset

# %%
! unzip stanford-dogs-dataset.zip -d dataset
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_117.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_11807.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_11875.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_122.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_12232.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_125.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_12738.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_12739.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_12827.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_13340.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_13526.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1353.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1355.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1357.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1367.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_13738.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_13839.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_13898.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_14074.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1410.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_14112.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1418.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_14659.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_14719.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_149.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1511.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_15432.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1560.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_15702.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1571.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1575.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1619.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1626.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1654.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1672.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1675.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1690.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1748.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1757.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1775.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1859.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1912.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_1956.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_200.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2007.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2056.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2106.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2355.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2360.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2367.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2432.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2482.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2526.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2608.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2653.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2670.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_268.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2718.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2723.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2740.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2741.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2791.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2796.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2815.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2831.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2917.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_2953.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3028.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3162.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3236.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3248.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3258.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3269.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3365.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3395.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3400.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3412.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3547.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3557.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3669.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_3899.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_395.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4002.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4042.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4076.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4119.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4158.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4440.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4486.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4681.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4730.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_485.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4865.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_4989.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5043.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_522.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5266.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_530.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5301.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_540.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5423.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5599.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5614.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5753.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_5977.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6008.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6223.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_625.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6295.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6418.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6429.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_6583.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_69.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_7259.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_7319.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_7431.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_7456.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_770.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_78.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_7853.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_813.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_836.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_849.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_8739.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_8969.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_9045.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_9076.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_922.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_926.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_931.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_959.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_9724.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_9778.jpg
#   inflating: dataset/images/Images/n02108089-boxer/n02108089_995.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1013.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1016.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1017.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1079.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1096.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1166.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1242.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1305.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1425.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1442.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1445.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1507.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1546.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1547.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1548.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1549.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_158.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_170.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1701.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1836.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1869.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1879.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1889.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1923.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1939.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1958.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1968.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_1975.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_200.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2046.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2052.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2053.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_207.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2082.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2094.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2111.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2123.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2203.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2207.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2209.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2290.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2297.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2338.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2344.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2353.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2379.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2404.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2441.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2443.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2471.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_251.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2623.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2678.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_278.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2867.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2947.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2949.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_2990.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3051.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3086.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3101.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_311.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3169.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3177.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3184.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3186.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3197.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3235.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3273.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3277.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3297.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3379.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3398.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3440.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_347.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3479.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3576.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3593.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3618.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3621.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3641.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3647.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3708.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3709.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_3711.jpg
#   inflating: dataset/images/Images/n02108422-bull_mastiff/n02108422_
jpg
#   inflating: dataset/images/Images/n02116738-African_hunting_dog/n02116738_9844.jpg
#   inflating: dataset/images/Images/n02116738-African_hunting_dog/n02116738_9924.jpg

# %%
os.listdir("/content/stan_dog_dataset/dataset")
# Out:
# ['images', 'annotations']

# %% [markdown]
# ## Создаем рабочий датасет

# %% [markdown]
# Пример взят отсюда https://www.kaggle.com/jingw222/stanford-dogbreeds-a-transfer-learning-tutorial#Confusion-matrix-analysis

# %%
import pathlib
import multiprocessing as mp
import xml.etree.ElementTree as ET
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf

# %%
# !ls
# Out:
# dataset  stanford-dogs-dataset.zip

# %%
ANNOTATION_DIR = pathlib.Path('./dataset/annotations/Annotation/')
IMAGES_DIR = pathlib.Path('./dataset/images/Images')

# %%
BREED_DIR = [path for path in IMAGES_DIR.iterdir()]
BREED_DIR_NAME = [path.name for path in BREED_DIR]

# %%
BREED_CODE_TO_NAME = {breed.split('-')[0]: breed[10:] for breed in BREED_DIR_NAME}
BREED_NAME_TO_CODE = {v: k for k, v in BREED_CODE_TO_NAME.items()}

BREED_LABEL_TO_CODE = {i: code for i, code in enumerate(BREED_CODE_TO_NAME)}
BREED_CODE_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_CODE.items()}

BREED_LABEL_TO_NAME = {i: BREED_CODE_TO_NAME[code] for i, code in BREED_LABEL_TO_CODE.items()}
BREED_NAME_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_NAME.items()}

# %%
def path_to_label(path):
    code = path.stem.split('_')[0]
    return BREED_CODE_TO_LABEL[code]


def get_all_file_path(directory, file_pattern=''):
    paths = list(f for f in directory.rglob('**/*{}'.format(file_pattern)) if f.is_file())
    return sorted(paths, key=str) 
    
    
all_image_paths = get_all_file_path(IMAGES_DIR, '.jpg') # PosixPath
all_image_labels = [path_to_label(path) for path in all_image_paths] # [0,1,2,...]

assert len(all_image_paths)==len(all_image_labels), 'Numbers of images and labels not match! {}!={}'.format(len(all_image_paths), len(all_image_labels))

# Write labels to file 
with open('labels.txt', 'w') as f:
    f.write('\n'.join(BREED_NAME_TO_LABEL))

# %%
# Crop and save images according to boundings
IMAGES_CROPPED_DIR = pathlib.Path('/tmp/images_cropped/')
IMAGES_CROPPED_DIR.mkdir(parents=True, exist_ok=True) 

# Gets object boundings
def parse_bounding(path):
    # Get annotation path from image path
    path = ANNOTATION_DIR / path.parent.name / path.stem
    
    # Parse boundings
    tree = ET.parse(path)
    bndbox = tree.getroot().findall('object')[0].find('bndbox')
    left = int(bndbox.find('xmin').text)
    right = int(bndbox.find('xmax').text) 
    upper = int(bndbox.find('ymin').text)
    lower = int(bndbox.find('ymax').text) 
    
    return (left, upper, right, lower)


def crop_and_save_image(path, save_dir=IMAGES_CROPPED_DIR):
    box = parse_bounding(path)
    
    image = Image.open(path)
    image_cropped = image.crop(box)
    image_cropped = image_cropped.convert('RGB')
    image_cropped.save(save_dir / path.name)

# %%
# Crop images according to bounding boxes
try:
    pool = mp.Pool(processes=mp.cpu_count())
    pool.map(crop_and_save_image, all_image_paths)
except Exception as e:
    print(e)
finally:
    pool.close()

    
all_image_cropped_paths = get_all_file_path(IMAGES_CROPPED_DIR, '.jpg') # PosixPath
all_image_cropped_labels = [path_to_label(path) for path in all_image_cropped_paths] # [0,1,2,...]

assert len(all_image_paths)==len(all_image_cropped_paths), 'Numbers of images and cropped images not match! {}!={}'.format(len(all_image_paths), len(all_image_cropped_paths))

# %%
# IMAGE_PATH = all_image_paths
# LABEL = all_image_labels
IMAGE_PATH = all_image_cropped_paths
LABEL = all_image_cropped_labels

# %%
IMAGE_PATH[:5]
# Out:
# [PosixPath('/tmp/images_cropped/n02085620_10074.jpg'),
#  PosixPath('/tmp/images_cropped/n02085620_10131.jpg'),
#  PosixPath('/tmp/images_cropped/n02085620_10621.jpg'),
#  PosixPath('/tmp/images_cropped/n02085620_1073.jpg'),
#  PosixPath('/tmp/images_cropped/n02085620_10976.jpg')]

# %%
LABEL[:5]
# Out:
# [26, 26, 26, 26, 26]

# %%
# Label distribution
_ = plt.hist(LABEL, bins=120)
plt.xlabel('Label index')
plt.ylabel('Count')
plt.title('Label Distribution')
plt.show()

# %%
# Ramdomly check a dog image from the dataset
dog = np.random.choice(IMAGE_PATH)
print('Random dog: ', BREED_LABEL_TO_NAME[path_to_label(dog)])
Image.open(dog)
# Out:
# Random dog:  West_Highland_white_terrier
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=491x330 at 0x7F0ACF751EF0>

# %% [markdown]
# ## Загрузка данных

# %%
RANDOM_SEED = 12345
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
TEST_SIZE = 0.2
INPUT_IMAGE_SIZE = 224

BATCH_SIZE = 24
EPOCH = 5

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
x_train, x_test, y_train, y_test = train_test_split(IMAGE_PATH, 
                                                    LABEL,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_SEED,
                                                    shuffle=True,
                                                    stratify=LABEL)

print('Train data: ', len(x_train))
print('Test data: ', len(x_test))
# Out:
# Train data:  16464
# Test data:  4116

# %%
def augmentation(image, label=None):
    image = tf.image.random_flip_left_right(image, seed=RANDOM_SEED)
    image = tf.image.random_brightness(image, max_delta=0.1, seed=RANDOM_SEED)
    image = tf.image.random_contrast(image, lower=0.9, upper=1.1, seed=RANDOM_SEED)
    if label is None:
        return image
    return image, label


def preprocess_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE])
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    return image


def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    return preprocess_image(image)


def load_and_preprocess_from_path_label(path, label):
    return load_and_preprocess_image(path), label

# %%
ds_train = tf.data.Dataset.from_tensor_slices(([str(path) for path in x_train], y_train))
ds_test = tf.data.Dataset.from_tensor_slices(([str(path) for path in x_test], y_test))

# Apply shuffle and repeat on training data
ds_train = ds_train.apply(
    tf.data.experimental.shuffle_and_repeat(buffer_size=len(x_train), seed=RANDOM_SEED))

# Preprocessing
ds_train = ds_train.map(load_and_preprocess_from_path_label, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.map(load_and_preprocess_from_path_label, num_parallel_calls=AUTOTUNE)

# Augmentation
# ds_train = ds_train.map(augmentation, num_parallel_calls=AUTOTUNE)

ds_train = ds_train.batch(BATCH_SIZE)
ds_test = ds_test.batch(BATCH_SIZE)

# `prefetch` lets the dataset fetch batches in the background while the model is training.
ds_train = ds_train.prefetch(buffer_size=1)
# Out:
# WARNING:tensorflow:From <ipython-input-37-cd025f063736>:6: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.

# %% [markdown]
# ## Создание модели (MobileNetV2)

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE, 3), include_top=False)
base_model.trainable = False

# %% [markdown]
# ### Применение Transfer learning

# %%
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(BREED_NAME_TO_LABEL), 
                          activation='softmax', 
                          kernel_initializer=tf.keras.initializers.glorot_normal(seed=RANDOM_SEED),
                          bias_initializer='zeros',
                          name='predictions')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 1280)              0
# _________________________________________________________________
# predictions (Dense)          (None, 120)               153720
# =================================================================
# Total params: 2,411,704
# Trainable params: 153,720
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Start training the model
steps_per_epoch = len(x_train)//BATCH_SIZE
history = model.fit(ds_train, epochs=EPOCH, validation_data=ds_test, steps_per_epoch=steps_per_epoch)
# Out:
# Epoch 1/5
# 686/686 [==============================] - 54s 78ms/step - loss: 0.9389 - accuracy: 0.7579 - val_loss: 0.5342 - val_accuracy: 0.8341
# Epoch 2/5
# 686/686 [==============================] - 53s 77ms/step - loss: 0.3486 - accuracy: 0.8929 - val_loss: 0.4877 - val_accuracy: 0.8496
# Epoch 3/5
# 686/686 [==============================] - 53s 77ms/step - loss: 0.2336 - accuracy: 0.9306 - val_loss: 0.5036 - val_accuracy: 0.8462
# Epoch 4/5
# 686/686 [==============================] - 53s 77ms/step - loss: 0.1609 - accuracy: 0.9570 - val_loss: 0.4970 - val_accuracy: 0.8518
# Epoch 5/5
# 686/686 [==============================] - 53s 77ms/step - loss: 0.1162 - accuracy: 0.9719 - val_loss: 0.4979 - val_accuracy: 0.8503

# %%
# Plot training & validation metrics
def plot_model_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Model Training Metrics')

    ax1.plot(history.history['accuracy'])
    ax1.plot(history.history['val_accuracy'])
    ax1.title.set_text('Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Valid'], loc='upper left')

    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.title.set_text('Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Valid'], loc='upper left')

    fig.show()
    
    
plot_model_history(history)

# %% [markdown]
# ## Создание модели (EfficientNetB4)

# %%
! pip install -U git+https://github.com/qubvel/efficientnet
# Out:
# Collecting git+https://github.com/qubvel/efficientnet
#   Cloning https://github.com/qubvel/efficientnet to /tmp/pip-req-build-88hd9mjh
#   Running command git clone -q https://github.com/qubvel/efficientnet /tmp/pip-req-build-88hd9mjh
# Requirement already satisfied, skipping upgrade: keras_applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (0.16.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (7.0.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.1.0) (4.4.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.8.1)
# Building wheels for collected packages: efficientnet
#   Building wheel for efficientnet (setup.py) ... done
#   Created wheel for efficientnet: filename=efficientnet-1.1.0-cp36-none-any.whl size=18327 sha256=b41367953a56cca71d01431e5b6dfac39b46cc6ab468cca4fec56c17add5d56b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7puk_q5o/wheels/64/60/2e/30ebaa76ed1626e86bfb0cc0579b737fdb7d9ff8cb9522663a
# Successfully built efficientnet
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.0

# %%
import efficientnet.tfkeras as efn

# %%
base_model = efn.EfficientNetB4(input_shape=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE, 3), include_top=False)

# %%
base_model.trainable = False

# %% [markdown]
# ### Применение Transfer learning

# %%
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(BREED_NAME_TO_LABEL), 
                          activation='softmax', 
                          kernel_initializer=tf.keras.initializers.glorot_normal(seed=RANDOM_SEED),
                          bias_initializer='zeros',
                          name='predictions')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b4 (Model)      (None, 7, 7, 1792)        17673816
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 1792)              0
# _________________________________________________________________
# predictions (Dense)          (None, 120)               215160
# =================================================================
# Total params: 17,888,976
# Trainable params: 215,160
# Non-trainable params: 17,673,816
# _________________________________________________________________

# %%
# Start training the model
steps_per_epoch = len(x_train)//BATCH_SIZE
history = model.fit(ds_train, epochs=EPOCH, validation_data=ds_test, steps_per_epoch=steps_per_epoch)
# Out:
# Epoch 1/5
# 686/686 [==============================] - 201s 293ms/step - loss: 0.9918 - accuracy: 0.8010 - val_loss: 0.3629 - val_accuracy: 0.8904
# Epoch 2/5
# 686/686 [==============================] - 198s 288ms/step - loss: 0.3799 - accuracy: 0.8836 - val_loss: 0.3310 - val_accuracy: 0.8960
# Epoch 3/5
# 686/686 [==============================] - 197s 287ms/step - loss: 0.3175 - accuracy: 0.8993 - val_loss: 0.3347 - val_accuracy: 0.8941
# Epoch 4/5
# 686/686 [==============================] - 196s 286ms/step - loss: 0.2715 - accuracy: 0.9114 - val_loss: 0.3392 - val_accuracy: 0.8938
# Epoch 5/5
# 686/686 [==============================] - 197s 288ms/step - loss: 0.2474 - accuracy: 0.9208 - val_loss: 0.3456 - val_accuracy: 0.8941

# %%
# Plot training & validation metrics
def plot_model_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Model Training Metrics')

    ax1.plot(history.history['accuracy'])
    ax1.plot(history.history['val_accuracy'])
    ax1.title.set_text('Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Valid'], loc='upper left')

    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.title.set_text('Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Valid'], loc='upper left')

    fig.show()
    
    
plot_model_history(history)
