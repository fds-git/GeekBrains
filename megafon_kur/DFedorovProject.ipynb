# %% [markdown]
# ## Подготовка датасетов

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import dask.dataframe as dd

# %%
test = pd.read_csv('data_test.csv')

# %%
train = pd.read_csv('data_train.csv')

# %%
train
# Out:
#         Unnamed: 0       id  vas_id    buy_time  target
# 0                0   540968     8.0  1537131600     0.0
# 1                1  1454121     4.0  1531688400     0.0
# 2                2  2458816     1.0  1534107600     0.0
# 3                3  3535012     5.0  1535922000     0.0
# 4                4  1693214     1.0  1535922000     0.0
# ...            ...      ...     ...         ...     ...
# 831648      831648  3812226     2.0  1546203600     0.0
# 831649      831649  2480469     2.0  1546203600     0.0
# 831650      831650   158236     2.0  1546203600     0.0
# 831651      831651  1825525     2.0  1546203600     0.0
# 831652      831652  3022610     2.0  1546203600     0.0
#
# [831653 rows x 5 columns]

# %%
test
# Out:
#        Unnamed: 0       id  vas_id    buy_time
# 0               0  3130519     2.0  1548018000
# 1               1  2000860     4.0  1548018000
# 2               2  1099444     2.0  1546808400
# 3               3  1343255     5.0  1547413200
# 4               4  1277040     2.0  1546808400
# ...           ...      ...     ...         ...
# 71226       71226  2502453     5.0  1548018000
# 71227       71227  1693213     2.0  1548018000
# 71228       71228  1891350     2.0  1548018000
# 71229       71229  2437172     2.0  1548018000
# 71230       71230   988236     2.0  1548018000
#
# [71231 rows x 4 columns]

# %%
train['id'].nunique()
# Out:
# 806613

# %% [markdown]
# Связывание features с features.csv через dask.dataframe

# %%
features = dd.read_csv('features.csv', blocksize=25e6, sep='\t')

# %% [markdown]
# Выбраем информацию о тех пользователях, которые присутствуют в train и test

# %%
features_train = features.loc[features['id'].isin(train['id'])].compute()

# %%
features_test = features.loc[features['id'].isin(test['id'])].compute()

# %% [markdown]
# ### Обзор features_train

# %% [markdown]
# Дубликатов строк нет

# %%
features_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В features_train есть несколько записей для пользователей с одним id

# %%
features_train.shape[0]
# Out:
# 834168

# %%
features_train['id'].nunique()
# Out:
# 806613

# %%
dif = features_train.shape[0] - features_train['id'].nunique()
dif
# Out:
# 27555

# %%
features_train[features_train['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#       Unnamed: 0       id    buy_time           0           1           2  \
# 3476     3664458      372  1544389200  159.560029 -100.259112  146.889214
# 893       982668      372  1544994000  -96.799971 -143.929112 -109.050786
# 3156      914805      404  1533502800  -78.159971  499.180888  -84.480786
# 4910     3600789      404  1540155600  354.550029  164.940888  526.199214
# 784      2890548      487  1544389200  -28.169971  -30.359112  119.749214
# ...          ...      ...         ...         ...         ...         ...
# 4208     4386322  4362012  1533502800   12.950029  -94.609112    0.699214
# 943      3261297  4362200  1535317200  199.810029  -94.879112  185.869214
# 4006     3419602  4362200  1542574800  -96.799971 -196.319112 -110.740786
# 2276      272785  4362538  1542574800  -96.799971 -160.309112  -72.610786
# 1702     1629490  4362538  1545598800    9.070029 -137.079112    3.609214
#
#                3           4          5          6  ...          243  \
# 3476 -110.936798  141.471754 -132.04179  -16.08618  ...  4405.626154
# 893  -174.096798 -114.468246 -195.20179  -16.08618  ...  -835.373846
# 3156  460.553202  -89.898246  439.44821  -16.08618  ...  -408.373846
# 4910  327.583202  520.781754  306.47821  403.40382  ...  2712.626154
# 784   417.873202  114.331754  396.76821  -16.08618  ...  -973.373846
# ...          ...         ...        ...        ...  ...          ...
# 4208 -133.656798   -4.718246 -154.76179  -16.08618  ...  -931.373846
# 943  -147.486798  180.451754 -168.59179  -16.08618  ...  -722.373846
# 4006 -248.926798 -116.158246 -270.03179  -16.08618  ...  -963.373846
# 2276 -170.546798  -78.028246 -191.65179  -16.08618  ...  -977.373846
# 1702 -155.776798   -1.808246 -176.88179  -16.08618  ...  -977.373846
#
#               244        245         246         247        248       249  \
# 3476  1933.229208 -25.996269  -37.630448   29.252276 -22.832889 -0.694428
# 893   -471.770792 -25.996269  -37.630448 -290.747724 -22.832889 -0.694428
# 3156  -588.770792 -25.996269  -22.630448  861.252276  34.167111 -0.694428
# 4910  1326.229208 -24.996269  102.369552  201.252276  30.167111 -0.694428
# 784   -613.770792 -25.996269   -9.630448   11.252276  45.167111  0.305572
# ...           ...        ...         ...         ...        ...       ...
# 4208  -604.770792 -23.996269  -37.630448 -143.747724 -24.832889 -0.694428
# 943   -360.770792 -25.996269  -37.630448   72.252276  31.167111  1.305572
# 4006  -599.770792 -22.996269  -35.630448 -192.747724 -21.832889  0.305572
# 2276  -613.770792 -25.996269  -37.630448 -280.747724 -25.832889 -0.694428
# 1702  -613.770792 -24.996269  -37.630448 -290.747724 -25.832889 -0.694428
#
#             250      251  252
# 3476 -12.175933 -0.45614  0.0
# 893  -12.175933 -0.45614  0.0
# 3156  47.824067 -0.45614  0.0
# 4910 -10.175933 -0.45614  0.0
# 784  -12.175933  2.54386  1.0
# ...         ...      ...  ...
# 4208 -11.175933 -0.45614  0.0
# 943   42.824067 -0.45614  0.0
# 4006 -12.175933 -0.45614  0.0
# 2276 -12.175933 -0.45614  0.0
# 1702 -12.175933 -0.45614  1.0
#
# [55110 rows x 256 columns]

# %%
dublicated = features_train[features_train['id'].duplicated(keep=False)].sort_values(by='id')['id'].value_counts()

# %%
dublicated
# Out:
# 2101246    2
# 3403223    2
# 2797023    2
# 3429856    2
# 1859041    2
#           ..
# 1653490    2
# 1782515    2
# 1706740    2
# 3762936    2
# 4003250    2
# Name: id, Length: 27555, dtype: int64

# %% [markdown]
# То есть 27555 пользователей имеют по 2 записи в features_train (по два профиля каждого такого пользователя). Их данные собраны в разное время. Поэтому сливать таблицы features_train и train надо с учетом столбца buy_time

# %% [markdown]
# ### Обзор train

# %%
train['id'].shape[0]
# Out:
# 831653

# %%
train['id'].nunique()
# Out:
# 806613

# %%
diff = train['id'].shape[0] - train['id'].nunique()

# %%
diff
# Out:
# 25040

# %%
train[train['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#         Unnamed: 0       id  vas_id    buy_time  target
# 14042        14042      342     2.0  1542574800     1.0
# 14041        14041      342     1.0  1541365200     0.0
# 19825        19825      492     6.0  1544994000     1.0
# 19824        19824      492     4.0  1538946000     0.0
# 22908        22908      579     4.0  1542574800     1.0
# ...            ...      ...     ...         ...     ...
# 751154      751154  4339012     2.0  1542574800     1.0
# 248700      248700  4347691     4.0  1543179600     0.0
# 248701      248701  4347691     6.0  1542574800     1.0
# 366175      366175  4350615     2.0  1544389200     1.0
# 366174      366174  4350615     1.0  1532293200     0.0
#
# [50042 rows x 5 columns]

# %% [markdown]
# То есть одни и те же пользователи в разные моменты времени подключали и отказывались от подключения разных услуг. Здесь нужно добавлять актуальный профиль пользователя из features_train (если их там неколько) на момент согласия или отказа.

# %% [markdown]
# ### Рассмотрим отдельную запись

# %% [markdown]
# В train пользователь 372 имеет одну запись, а в features_train - 2 профиля потребления. Из features_train надо добавлять тот профиль, который был ближе по времени.

# %%
a = features_train.loc[features_train['id']==372]

# %%
b = train.loc[train['id']==372]

# %%
a
# Out:
#       Unnamed: 0   id    buy_time           0           1           2  \
# 893       982668  372  1544994000  -96.799971 -143.929112 -109.050786
# 3476     3664458  372  1544389200  159.560029 -100.259112  146.889214
#
#                3           4          5         6  ...          243  \
# 893  -174.096798 -114.468246 -195.20179 -16.08618  ...  -835.373846
# 3476 -110.936798  141.471754 -132.04179 -16.08618  ...  4405.626154
#
#               244        245        246         247        248       249  \
# 893   -471.770792 -25.996269 -37.630448 -290.747724 -22.832889 -0.694428
# 3476  1933.229208 -25.996269 -37.630448   29.252276 -22.832889 -0.694428
#
#             250      251  252
# 893  -12.175933 -0.45614  0.0
# 3476 -12.175933 -0.45614  0.0
#
# [2 rows x 256 columns]

# %%
a = a.sort_values(by='buy_time')

# %%
b
# Out:
#        Unnamed: 0   id  vas_id    buy_time  target
# 15681       15681  372     4.0  1535922000     0.0

# %%
# Если делать через merge_asof, то в результате будет много строк, содержащих NaN, так как для многих пользователей 
# buy_time в train был зафиксирован раньше, чем профиль пользователя
c = pd.merge_asof(b, a, on='buy_time', by='id')

# %%
c
# Out:
#    Unnamed: 0_x   id  vas_id    buy_time  target  Unnamed: 0_y   0   1   2  \
# 0         15681  372     4.0  1535922000     0.0           NaN NaN NaN NaN
#
#     3  ...  243  244  245  246  247  248  249  250  251  252
# 0 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 259 columns]

# %%
# Если делать через merge, то данные будут дублироваться. Необходимо удалить все дубли кроме тех, в которых разность
# между buy_time_x и buy_time_y минимальна. 
c = pd.merge(b, a, on='id')
c
# Out:
#    Unnamed: 0_x   id  vas_id  buy_time_x  target  Unnamed: 0_y  buy_time_y  \
# 0         15681  372     4.0  1535922000     0.0       3664458  1544389200
# 1         15681  372     4.0  1535922000     0.0        982668  1544994000
#
#             0           1           2  ...          243          244  \
# 0  159.560029 -100.259112  146.889214  ...  4405.626154  1933.229208
# 1  -96.799971 -143.929112 -109.050786  ...  -835.373846  -471.770792
#
#          245        246         247        248       249        250      251  \
# 0 -25.996269 -37.630448   29.252276 -22.832889 -0.694428 -12.175933 -0.45614
# 1 -25.996269 -37.630448 -290.747724 -22.832889 -0.694428 -12.175933 -0.45614
#
#    252
# 0  0.0
# 1  0.0
#
# [2 rows x 260 columns]

# %% [markdown]
# ### Объединение train и features_train

# %%
train = pd.merge(train, features_train, on='id')

# %%
train
# Out:
#         Unnamed: 0_x       id  vas_id  buy_time_x  target  Unnamed: 0_y  \
# 0                  0   540968     8.0  1537131600     0.0       3756522
# 1                  1  1454121     4.0  1531688400     0.0       2735973
# 2                  2  2458816     1.0  1534107600     0.0       3586550
# 3                  3  3535012     5.0  1535922000     0.0       1634974
# 4                  4  1693214     1.0  1535922000     0.0        716515
# ...              ...      ...     ...         ...     ...           ...
# 860047        831648  3812226     2.0  1546203600     0.0       3598646
# 860048        831649  2480469     2.0  1546203600     0.0       1126545
# 860049        831650   158236     2.0  1546203600     0.0       3755060
# 860050        831651  1825525     2.0  1546203600     0.0        253884
# 860051        831652  3022610     2.0  1546203600     0.0       2556316
#
#         buy_time_y           0           1           2  ...          243  \
# 0       1541970000  -31.559971  327.360888  -45.500786  ...  -845.373846
# 1       1531083600  547.270029  238.430888  533.329214  ...  -972.373846
# 2       1543179600  -92.139971  -95.469112 -106.080786  ...  -977.373846
# 3       1533502800   54.880029   12.970888   54.079214  ...  -977.373846
# 4       1543179600   45.160029  295.240888   64.679214  ...  -965.373846
# ...            ...         ...         ...         ...  ...          ...
# 860047  1532898000   29.750029    6.200888   24.279214  ...  -977.373846
# 860048  1532293200  -89.179971  -56.499112 -103.120786  ...   -66.373846
# 860049  1538946000  -96.799971   62.140888 -110.740786  ...  -683.373846
# 860050  1533502800  -96.799971  -81.919112 -110.740786  ...  1018.626154
# 860051  1540760400  -49.339971 -218.339112   73.139214  ...  -977.373846
#
#                 244        245        246          247         248       249  \
# 0       -613.770792 -20.996269 -37.630448   -28.747724    4.167111  7.305572
# 1       -613.770792 -25.996269 -19.630448  -278.747724  -24.832889 -0.694428
# 2       -613.770792 -25.996269 -37.630448  -304.747724  -25.832889 -0.694428
# 3       -613.770792 -25.996269 -18.630448  -133.747724  -14.832889 -0.694428
# 4       -612.770792 -22.996269 -32.630448  -127.747724   -4.832889 -0.694428
# ...             ...        ...        ...          ...         ...       ...
# 860047  -613.770792 -25.996269 -37.630448  -306.747724  -25.832889 -0.694428
# 860048  -321.770792 -25.996269  62.369552  1167.252276   41.167111 -0.694428
# 860049  -470.770792 -25.996269 -37.630448    99.252276  178.167111 -0.694428
# 860050  1367.229208 -24.996269 -35.630448  -237.747724  -21.832889 -0.694428
# 860051  -613.770792 -25.996269 -37.630448  -303.747724  -25.832889 -0.694428
#
#                250       251  252
# 0       -12.175933  21.54386  0.0
# 1       -11.175933  -0.45614  0.0
# 2       -12.175933  -0.45614  0.0
# 3        -1.175933  -0.45614  0.0
# 4       -12.175933  -0.45614  0.0
# ...            ...       ...  ...
# 860047  -12.175933  -0.45614  0.0
# 860048   54.824067  -0.45614  0.0
# 860049  191.824067  -0.45614  0.0
# 860050   -8.175933  -0.45614  1.0
# 860051  -12.175933  -0.45614  0.0
#
# [860052 rows x 260 columns]

# %%
train['1'].isnull().sum()
# Out:
# 0

# %%
tmp = train.loc[train['id'].isin(dublicated.index)]

# %%
tmp
# Out:
#         Unnamed: 0_x       id  vas_id  buy_time_x  target  Unnamed: 0_y  \
# 8                  8  2000856     1.0  1534712400     0.0       2114914
# 9                  8  2000856     1.0  1534712400     0.0       4145047
# 58                57  3577738     1.0  1532293200     0.0       2986290
# 59                57  3577738     1.0  1532293200     0.0       3235297
# 63                61   203194     1.0  1532293200     0.0        146332
# ...              ...      ...     ...         ...     ...           ...
# 859986        831589  2524068     2.0  1546203600     0.0       3070401
# 860000        831603  3897343     2.0  1546203600     0.0       2512976
# 860001        831603  3897343     2.0  1546203600     0.0       4384546
# 860029        831631  3431643     5.0  1546203600     0.0        995025
# 860030        831631  3431643     5.0  1546203600     0.0       2956445
#
#         buy_time_y          0           1           2  ...           243  \
# 8       1531688400 -21.369971  108.780888  178.619214  ...   -977.373846
# 9       1531083600 -92.559971   48.600888   50.239214  ...   -977.373846
# 58      1540760400 -96.799971   45.210888 -104.810786  ...   -929.373846
# 59      1537736400 -96.799971  104.530888   -8.220786  ...   -969.373846
# 63      1542574800 -96.799971 -111.569112 -110.740786  ...   -977.373846
# ...            ...        ...         ...         ...  ...           ...
# 859986  1546203600  21.700029  121.340888    7.759214  ...  63574.626154
# 860000  1544994000 -96.799971 -408.179112 -110.740786  ...   -977.373846
# 860001  1532293200 -61.909971 -212.729112  -75.850786  ...   -977.373846
# 860029  1547413200 -95.299971 -248.349112 -109.240786  ...   -642.373846
# 860030  1544389200 -96.799971 -166.649112 -110.740786  ...     85.626154
#
#                244        245        246         247        248       249  \
# 8      -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 9      -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 58     -565.770792 -25.996269 -28.630448 -177.747724 -25.832889 -0.694428
# 59     -605.770792 -25.996269 -35.630448 -159.747724 -25.832889 -0.694428
# 63     -613.770792 -25.996269 -37.630448 -258.747724 -24.832889 -0.694428
# ...            ...        ...        ...         ...        ...       ...
# 859986 -584.770792 -25.996269 -31.630448 -237.747724 -23.832889 -0.694428
# 860000 -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 860001 -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 860029 -613.770792 -25.996269 -37.630448 -186.747724 -25.832889 -0.694428
# 860030  448.229208 -25.996269 -37.630448  143.252276 -25.832889 -0.694428
#
#               250      251  252
# 8      -12.175933 -0.45614  0.0
# 9      -12.175933 -0.45614  0.0
# 58     -12.175933 -0.45614  0.0
# 59     -12.175933 -0.45614  0.0
# 63     -12.175933 -0.45614  0.0
# ...           ...      ...  ...
# 859986 -12.175933 -0.45614  0.0
# 860000 -12.175933 -0.45614  0.0
# 860001 -12.175933 -0.45614  0.0
# 860029 -12.175933 -0.45614  0.0
# 860030 -12.175933 -0.45614  0.0
#
# [56798 rows x 260 columns]

# %% [markdown]
# Получили 56798 дублированных строк. Оставим только те, у которых разность между buy_time_x и buy_time_y минимальна. Создадаим переменную delta.

# %%
tmp['delta'] = abs(tmp['buy_time_x'] - tmp['buy_time_y'])
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp
# Out:
#         Unnamed: 0_x       id  vas_id  buy_time_x  target  Unnamed: 0_y  \
# 8                  8  2000856     1.0  1534712400     0.0       2114914
# 9                  8  2000856     1.0  1534712400     0.0       4145047
# 58                57  3577738     1.0  1532293200     0.0       2986290
# 59                57  3577738     1.0  1532293200     0.0       3235297
# 63                61   203194     1.0  1532293200     0.0        146332
# ...              ...      ...     ...         ...     ...           ...
# 859986        831589  2524068     2.0  1546203600     0.0       3070401
# 860000        831603  3897343     2.0  1546203600     0.0       2512976
# 860001        831603  3897343     2.0  1546203600     0.0       4384546
# 860029        831631  3431643     5.0  1546203600     0.0        995025
# 860030        831631  3431643     5.0  1546203600     0.0       2956445
#
#         buy_time_y          0           1           2  ...         244  \
# 8       1531688400 -21.369971  108.780888  178.619214  ... -613.770792
# 9       1531083600 -92.559971   48.600888   50.239214  ... -613.770792
# 58      1540760400 -96.799971   45.210888 -104.810786  ... -565.770792
# 59      1537736400 -96.799971  104.530888   -8.220786  ... -605.770792
# 63      1542574800 -96.799971 -111.569112 -110.740786  ... -613.770792
# ...            ...        ...         ...         ...  ...         ...
# 859986  1546203600  21.700029  121.340888    7.759214  ... -584.770792
# 860000  1544994000 -96.799971 -408.179112 -110.740786  ... -613.770792
# 860001  1532293200 -61.909971 -212.729112  -75.850786  ... -613.770792
# 860029  1547413200 -95.299971 -248.349112 -109.240786  ... -613.770792
# 860030  1544389200 -96.799971 -166.649112 -110.740786  ...  448.229208
#
#               245        246         247        248       249        250  \
# 8      -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 9      -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 58     -25.996269 -28.630448 -177.747724 -25.832889 -0.694428 -12.175933
# 59     -25.996269 -35.630448 -159.747724 -25.832889 -0.694428 -12.175933
# 63     -25.996269 -37.630448 -258.747724 -24.832889 -0.694428 -12.175933
# ...           ...        ...         ...        ...       ...        ...
# 859986 -25.996269 -31.630448 -237.747724 -23.832889 -0.694428 -12.175933
# 860000 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 860001 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 860029 -25.996269 -37.630448 -186.747724 -25.832889 -0.694428 -12.175933
# 860030 -25.996269 -37.630448  143.252276 -25.832889 -0.694428 -12.175933
#
#             251  252     delta
# 8      -0.45614  0.0   3024000
# 9      -0.45614  0.0   3628800
# 58     -0.45614  0.0   8467200
# 59     -0.45614  0.0   5443200
# 63     -0.45614  0.0  10281600
# ...         ...  ...       ...
# 859986 -0.45614  0.0         0
# 860000 -0.45614  0.0   1209600
# 860001 -0.45614  0.0  13910400
# 860029 -0.45614  0.0   1209600
# 860030 -0.45614  0.0   1814400
#
# [56798 rows x 261 columns]

# %% [markdown]
# Отсортируем tmp по id и delta

# %%
tmp.sort_values(by = ['Unnamed: 0_x', 'delta'], inplace=True)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp
# Out:
#         Unnamed: 0_x       id  vas_id  buy_time_x  target  Unnamed: 0_y  \
# 8                  8  2000856     1.0  1534712400     0.0       2114914
# 9                  8  2000856     1.0  1534712400     0.0       4145047
# 59                57  3577738     1.0  1532293200     0.0       3235297
# 58                57  3577738     1.0  1532293200     0.0       2986290
# 64                61   203194     1.0  1532293200     0.0       2041758
# ...              ...      ...     ...         ...     ...           ...
# 859985        831589  2524068     2.0  1546203600     0.0       1537855
# 860000        831603  3897343     2.0  1546203600     0.0       2512976
# 860001        831603  3897343     2.0  1546203600     0.0       4384546
# 860029        831631  3431643     5.0  1546203600     0.0        995025
# 860030        831631  3431643     5.0  1546203600     0.0       2956445
#
#         buy_time_y          0           1           2  ...         244  \
# 8       1531688400 -21.369971  108.780888  178.619214  ... -613.770792
# 9       1531083600 -92.559971   48.600888   50.239214  ... -613.770792
# 59      1537736400 -96.799971  104.530888   -8.220786  ... -605.770792
# 58      1540760400 -96.799971   45.210888 -104.810786  ... -565.770792
# 64      1540760400 -96.799971 -170.889112 -110.740786  ... -613.770792
# ...            ...        ...         ...         ...  ...         ...
# 859985  1540760400 -79.839971   -9.859112  -93.780786  ... -613.770792
# 860000  1544994000 -96.799971 -408.179112 -110.740786  ... -613.770792
# 860001  1532293200 -61.909971 -212.729112  -75.850786  ... -613.770792
# 860029  1547413200 -95.299971 -248.349112 -109.240786  ... -613.770792
# 860030  1544389200 -96.799971 -166.649112 -110.740786  ...  448.229208
#
#               245        246         247        248       249        250  \
# 8      -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 9      -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 59     -25.996269 -35.630448 -159.747724 -25.832889 -0.694428 -12.175933
# 58     -25.996269 -28.630448 -177.747724 -25.832889 -0.694428 -12.175933
# 64     -25.996269 -37.630448 -297.747724 -25.832889 -0.694428 -12.175933
# ...           ...        ...         ...        ...       ...        ...
# 859985 -25.996269 -37.630448 -300.747724 -25.832889 -0.694428 -12.175933
# 860000 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 860001 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 860029 -25.996269 -37.630448 -186.747724 -25.832889 -0.694428 -12.175933
# 860030 -25.996269 -37.630448  143.252276 -25.832889 -0.694428 -12.175933
#
#             251  252     delta
# 8      -0.45614  0.0   3024000
# 9      -0.45614  0.0   3628800
# 59     -0.45614  0.0   5443200
# 58     -0.45614  0.0   8467200
# 64     -0.45614  0.0   8467200
# ...         ...  ...       ...
# 859985 -0.45614  0.0   5443200
# 860000 -0.45614  0.0   1209600
# 860001 -0.45614  0.0  13910400
# 860029 -0.45614  0.0   1209600
# 860030 -0.45614  0.0   1814400
#
# [56798 rows x 261 columns]

# %%
tmp['Unnamed: 0_x'].value_counts()
# Out:
# 460799    2
# 288198    2
# 757922    2
# 333224    2
# 722346    2
#          ..
# 47778     2
# 430759    2
# 447253    2
# 815491    2
# 663556    2
# Name: Unnamed: 0_x, Length: 28399, dtype: int64

# %%
del_idx = tmp['Unnamed: 0_x'].duplicated()

# %%
del_idx
# Out:
# 8         False
# 9          True
# 59        False
# 58         True
# 64        False
#           ...
# 859985     True
# 860000    False
# 860001     True
# 860029    False
# 860030     True
# Name: Unnamed: 0_x, Length: 56798, dtype: bool

# %% [markdown]
# Нужно удалить строки из train, индексы которых стоят напротив True в del_idx (они обладают большим значением delta)

# %%
del_idx = del_idx[del_idx.values == True]

# %%
del_idx
# Out:
# 9         True
# 58        True
# 63        True
# 65        True
# 86        True
#           ...
# 859892    True
# 859895    True
# 859985    True
# 860001    True
# 860030    True
# Name: Unnamed: 0_x, Length: 28399, dtype: bool

# %%
train.drop(del_idx.index, axis=0, inplace=True)

# %%
train
# Out:
#         Unnamed: 0_x       id  vas_id  buy_time_x  target  Unnamed: 0_y  \
# 0                  0   540968     8.0  1537131600     0.0       3756522
# 1                  1  1454121     4.0  1531688400     0.0       2735973
# 2                  2  2458816     1.0  1534107600     0.0       3586550
# 3                  3  3535012     5.0  1535922000     0.0       1634974
# 4                  4  1693214     1.0  1535922000     0.0        716515
# ...              ...      ...     ...         ...     ...           ...
# 860047        831648  3812226     2.0  1546203600     0.0       3598646
# 860048        831649  2480469     2.0  1546203600     0.0       1126545
# 860049        831650   158236     2.0  1546203600     0.0       3755060
# 860050        831651  1825525     2.0  1546203600     0.0        253884
# 860051        831652  3022610     2.0  1546203600     0.0       2556316
#
#         buy_time_y           0           1           2  ...          243  \
# 0       1541970000  -31.559971  327.360888  -45.500786  ...  -845.373846
# 1       1531083600  547.270029  238.430888  533.329214  ...  -972.373846
# 2       1543179600  -92.139971  -95.469112 -106.080786  ...  -977.373846
# 3       1533502800   54.880029   12.970888   54.079214  ...  -977.373846
# 4       1543179600   45.160029  295.240888   64.679214  ...  -965.373846
# ...            ...         ...         ...         ...  ...          ...
# 860047  1532898000   29.750029    6.200888   24.279214  ...  -977.373846
# 860048  1532293200  -89.179971  -56.499112 -103.120786  ...   -66.373846
# 860049  1538946000  -96.799971   62.140888 -110.740786  ...  -683.373846
# 860050  1533502800  -96.799971  -81.919112 -110.740786  ...  1018.626154
# 860051  1540760400  -49.339971 -218.339112   73.139214  ...  -977.373846
#
#                 244        245        246          247         248       249  \
# 0       -613.770792 -20.996269 -37.630448   -28.747724    4.167111  7.305572
# 1       -613.770792 -25.996269 -19.630448  -278.747724  -24.832889 -0.694428
# 2       -613.770792 -25.996269 -37.630448  -304.747724  -25.832889 -0.694428
# 3       -613.770792 -25.996269 -18.630448  -133.747724  -14.832889 -0.694428
# 4       -612.770792 -22.996269 -32.630448  -127.747724   -4.832889 -0.694428
# ...             ...        ...        ...          ...         ...       ...
# 860047  -613.770792 -25.996269 -37.630448  -306.747724  -25.832889 -0.694428
# 860048  -321.770792 -25.996269  62.369552  1167.252276   41.167111 -0.694428
# 860049  -470.770792 -25.996269 -37.630448    99.252276  178.167111 -0.694428
# 860050  1367.229208 -24.996269 -35.630448  -237.747724  -21.832889 -0.694428
# 860051  -613.770792 -25.996269 -37.630448  -303.747724  -25.832889 -0.694428
#
#                250       251  252
# 0       -12.175933  21.54386  0.0
# 1       -11.175933  -0.45614  0.0
# 2       -12.175933  -0.45614  0.0
# 3        -1.175933  -0.45614  0.0
# 4       -12.175933  -0.45614  0.0
# ...            ...       ...  ...
# 860047  -12.175933  -0.45614  0.0
# 860048   54.824067  -0.45614  0.0
# 860049  191.824067  -0.45614  0.0
# 860050   -8.175933  -0.45614  1.0
# 860051  -12.175933  -0.45614  0.0
#
# [831653 rows x 260 columns]

# %% [markdown]
# Итого количество строк равно количеству строк в train. Если для данного пользователя в features_train было несколько записей, учитываем только ту, которая по времени была ближе к той, которая в train

# %%
train.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'buy_time_y'], axis=1, inplace=True)

# %%
train
# Out:
#              id  vas_id  buy_time_x  target           0           1  \
# 0        540968     8.0  1537131600     0.0  -31.559971  327.360888
# 1       1454121     4.0  1531688400     0.0  547.270029  238.430888
# 2       2458816     1.0  1534107600     0.0  -92.139971  -95.469112
# 3       3535012     5.0  1535922000     0.0   54.880029   12.970888
# 4       1693214     1.0  1535922000     0.0   45.160029  295.240888
# ...         ...     ...         ...     ...         ...         ...
# 860047  3812226     2.0  1546203600     0.0   29.750029    6.200888
# 860048  2480469     2.0  1546203600     0.0  -89.179971  -56.499112
# 860049   158236     2.0  1546203600     0.0  -96.799971   62.140888
# 860050  1825525     2.0  1546203600     0.0  -96.799971  -81.919112
# 860051  3022610     2.0  1546203600     0.0  -49.339971 -218.339112
#
#                  2           3           4          5  ...          243  \
# 0       -45.500786  274.753202  -50.918246  253.64821  ...  -845.373846
# 1       533.329214  274.803202  527.911754  253.69821  ...  -972.373846
# 2      -106.080786 -139.596798 -111.498246 -142.90179  ...  -977.373846
# 3        54.079214   -9.116798   48.661754  -30.22179  ...  -977.373846
# 4        64.679214  344.283202   59.261754  323.17821  ...  -965.373846
# ...            ...         ...         ...        ...  ...          ...
# 860047   24.279214  -37.936798   18.861754  -59.04179  ...  -977.373846
# 860048 -103.120786 -109.106798 -108.538246 -130.21179  ...   -66.373846
# 860049 -110.740786    9.533202 -116.158246  -11.57179  ...  -683.373846
# 860050 -110.740786 -128.596798 -116.158246  -76.82179  ...  1018.626154
# 860051   73.139214  145.093202   67.721754  123.98821  ...  -977.373846
#
#                 244        245        246          247         248       249  \
# 0       -613.770792 -20.996269 -37.630448   -28.747724    4.167111  7.305572
# 1       -613.770792 -25.996269 -19.630448  -278.747724  -24.832889 -0.694428
# 2       -613.770792 -25.996269 -37.630448  -304.747724  -25.832889 -0.694428
# 3       -613.770792 -25.996269 -18.630448  -133.747724  -14.832889 -0.694428
# 4       -612.770792 -22.996269 -32.630448  -127.747724   -4.832889 -0.694428
# ...             ...        ...        ...          ...         ...       ...
# 860047  -613.770792 -25.996269 -37.630448  -306.747724  -25.832889 -0.694428
# 860048  -321.770792 -25.996269  62.369552  1167.252276   41.167111 -0.694428
# 860049  -470.770792 -25.996269 -37.630448    99.252276  178.167111 -0.694428
# 860050  1367.229208 -24.996269 -35.630448  -237.747724  -21.832889 -0.694428
# 860051  -613.770792 -25.996269 -37.630448  -303.747724  -25.832889 -0.694428
#
#                250       251  252
# 0       -12.175933  21.54386  0.0
# 1       -11.175933  -0.45614  0.0
# 2       -12.175933  -0.45614  0.0
# 3        -1.175933  -0.45614  0.0
# 4       -12.175933  -0.45614  0.0
# ...            ...       ...  ...
# 860047  -12.175933  -0.45614  0.0
# 860048   54.824067  -0.45614  0.0
# 860049  191.824067  -0.45614  0.0
# 860050   -8.175933  -0.45614  1.0
# 860051  -12.175933  -0.45614  0.0
#
# [831653 rows x 257 columns]

# %% [markdown]
# ### Обзор features_test

# %% [markdown]
# Дубликатов строк нет

# %%
features_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Есть разные строки с одинаковыми id

# %%
dif = features_test.shape[0] - features_test['id'].nunique()
dif
# Out:
# 2400

# %%
features_test[features_test['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#       Unnamed: 0       id    buy_time           0           1           2  \
# 4741        9755     1544  1535317200   56.090029   46.140888  126.899214
# 2444     1995811     1544  1546203600   68.940029   11.930888  182.759214
# 4071     2167703     4279  1545598800  -34.499971 -142.449112  -45.900786
# 3581     4265509     4279  1546203600  -35.399971 -143.349112  -49.340786
# 4923      340551    10021  1546808400  -85.109971 -384.779112  -77.400786
# ...          ...      ...         ...         ...         ...         ...
# 2662     1109634  4361372  1534712400  -96.799971 -170.889112 -110.740786
# 662       236110  4361999  1542574800  411.670029  107.920888  427.389214
# 4239     4025788  4361999  1544389200  -96.799971  100.290888 -110.740786
# 4507     2989424  4362664  1546203600  -95.109971 -403.089112 -109.050786
# 4309     3980788  4362664  1532898000  -93.409971 -398.849112 -107.350786
#
#                3           4          5         6  ...         243  \
# 4741   78.283202  121.481754   57.17821 -16.08618  ... -974.373846
# 2444  415.013202  177.341754  393.90821 -16.08618  ... -883.373846
# 4071 -192.516798  -51.318246 -213.62179 -16.08618  ... -977.373846
# 3581 -193.416798  -54.758246 -214.52179 -16.08618  ... -977.373846
# 4923 -398.196798  -82.818246 -419.30179 -16.08618  ... -977.373846
# ...          ...         ...        ...       ...  ...         ...
# 2662 -223.496798 -116.158246 -244.60179 -16.08618  ... -791.373846
# 662    84.973202  423.501754   66.92821 -16.08618  ...  612.626154
# 4239   77.343202 -116.158246   62.35821 -16.08618  ...  857.626154
# 4507 -455.696798 -114.468246 -476.80179 -16.08618  ... -977.373846
# 4309 -451.456798 -112.768246 -472.56179 -16.08618  ... -977.373846
#
#              244         245        246         247        248       249  \
# 4741 -613.770792  -23.996269 -37.630448 -179.747724 -14.832889 -0.694428
# 2444 -541.770792  -22.996269 -37.630448   68.252276  -4.832889 -0.694428
# 4071 -613.770792  -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 3581 -613.770792  -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 4923 -613.770792  -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# ...          ...         ...        ...         ...        ...       ...
# 2662 -519.770792  -25.996269 -36.630448 -146.747724  -6.832889 -0.694428
# 662   616.229208   23.003731  79.369552  622.252276 -25.832889 -0.694428
# 4239  922.229208  108.003731  47.369552 -143.747724 -25.832889 -0.694428
# 4507 -613.770792  -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 4309 -613.770792  -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
#
#             250      251  252
# 4741  -1.175933 -0.45614  0.0
# 2444 -12.175933 -0.45614  1.0
# 4071 -12.175933 -0.45614  0.0
# 3581 -12.175933 -0.45614  0.0
# 4923 -12.175933 -0.45614  0.0
# ...         ...      ...  ...
# 2662   6.824067 -0.45614  0.0
# 662  -12.175933 -0.45614  1.0
# 4239 -12.175933 -0.45614  0.0
# 4507 -12.175933 -0.45614  0.0
# 4309 -12.175933 -0.45614  0.0
#
# [4800 rows x 256 columns]

# %%
dublicated = features_test[features_test['id'].duplicated(keep=False)].sort_values(by='id')['id'].value_counts()

# %%
dublicated
# Out:
# 186365     2
# 506522     2
# 3840662    2
# 3912339    2
# 1825422    2
#           ..
# 1748755    2
# 3605502    2
# 1291656    2
# 2010499    2
# 1994754    2
# Name: id, Length: 2400, dtype: int64

# %% [markdown]
# В features_test для 2400 пользователей существует по 2 записи

# %% [markdown]
# ### Обзор test

# %%
diff = test['id'].shape[0] - test['id'].nunique()

# %%
diff
# Out:
# 1079

# %%
test[test['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#        Unnamed: 0       id  vas_id    buy_time
# 552           552      274     4.0  1548018000
# 551           551      274     2.0  1547413200
# 10677       10677     4770     4.0  1547413200
# 10676       10676     4770     2.0  1548018000
# 20241       20241     8166     1.0  1546808400
# ...           ...      ...     ...         ...
# 47995       47995  4231949     2.0  1546808400
# 69800       69800  4256618     2.0  1546808400
# 69801       69801  4256618     6.0  1548018000
# 17218       17218  4348306     4.0  1546808400
# 17219       17219  4348306     6.0  1546808400
#
# [2139 rows x 4 columns]

# %% [markdown]
# В test одни и те же пользователи в разные моменты времени подключали и отказывались подключать разные услуги

# %% [markdown]
# ### Объединение test и features_test

# %% [markdown]
# Обработка данных аналогична train и features_train. features_test есть несколько записей для определенного числа пользователей. Поэтому в test из нее будем добавлять строку, у которой значение buy_time максимально близкое к аналогичному значению

# %%
features_test
# Out:
#      Unnamed: 0       id    buy_time           0           1           2  \
# 141         141  2522732  1539550800  -93.749971  -64.949112  -99.210786
# 274         274  3504271  1548018000  386.530029   75.150888  372.589214
# 300         300  3556316  1539550800  -96.799971 -183.599112 -110.740786
# 324         324  3578987  1532898000   81.140029   32.440888   70.589214
# 399         399  3662585  1533502800  -96.799971 -372.579112 -110.740786
# ..          ...      ...         ...         ...         ...         ...
# 75      4512390  3488214  1545598800  157.440029  712.940888  143.499214
# 118     4512433  3495222  1545598800  -93.409971 -281.909112 -103.110786
# 121     4512436  3495970  1547413200  -12.239971  -72.559112  -26.180786
# 148     4512463  3505955  1548018000  -96.799971   50.150888 -110.740786
# 188     4512503  3516552  1547413200  -96.799971 -116.519112 -110.740786
#
#               3           4          5         6  ...           243  \
# 141 -100.596798 -104.628246 -103.92179 -16.08618  ...   -977.373846
# 274   39.133202  367.171754   18.02821 -16.08618  ...   -909.373846
# 300 -236.206798 -116.158246 -257.31179 -16.08618  ...   -898.373846
# 324  -13.386798   65.171754  -34.49179 -16.08618  ...     -6.373846
# 399 -425.186798 -116.158246 -446.29179 -16.08618  ...   -411.373846
# ..          ...         ...        ...       ...  ...           ...
# 75   660.333202  138.081754  639.22821 -16.08618  ...     75.626154
# 118 -330.276798 -108.528246 -351.38179 -12.69618  ...  10658.626154
# 121 -120.926798  -31.598246 -142.03179 -16.08618  ...   -966.373846
# 148    1.713202 -116.158246  -19.39179 -16.08618  ...    748.626154
# 188 -169.126798 -116.158246 -190.23179 -16.08618  ...   -975.373846
#
#              244         245        246          247        248       249  \
# 141  -613.770792  -17.996269 -36.630448  -212.747724   2.167111 -0.694428
# 274  -545.770792  -25.996269 -37.630448  -231.747724 -25.832889 -0.694428
# 300  -534.770792  -25.996269 -37.630448   -47.747724 -22.832889  0.305572
# 324  -578.770792  -25.996269 -37.630448  -111.747724  41.167111 -0.694428
# 399  -607.770792  -25.996269 -29.630448  -255.747724 -22.832889 -0.694428
# ..           ...         ...        ...          ...        ...       ...
# 75    384.229208  -25.996269 -37.630448  -192.747724 -24.832889 -0.694428
# 118  9726.229208  -25.996269 -28.630448   808.252276 -18.832889 -0.694428
# 121  -602.770792  -25.996269 -37.630448  -211.747724 -25.832889 -0.694428
# 148  1054.229208  716.003731 -37.630448  1208.252276 -24.832889 -0.694428
# 188  -613.770792  -25.996269 -37.630448    -5.747724 -24.832889 -0.694428
#
#            250      251  252
# 141 -12.175933 -0.45614  1.0
# 274 -12.175933 -0.45614  0.0
# 300 -11.175933 -0.45614  0.0
# 324  54.824067 -0.45614  0.0
# 399  -9.175933 -0.45614  1.0
# ..         ...      ...  ...
# 75  -12.175933 -0.45614  0.0
# 118 -12.175933 -0.45614  0.0
# 121 -12.175933 -0.45614  0.0
# 148 -12.175933 -0.45614  1.0
# 188 -12.175933 -0.45614  0.0
#
# [72552 rows x 256 columns]

# %%
test
# Out:
#        Unnamed: 0       id  vas_id    buy_time
# 0               0  3130519     2.0  1548018000
# 1               1  2000860     4.0  1548018000
# 2               2  1099444     2.0  1546808400
# 3               3  1343255     5.0  1547413200
# 4               4  1277040     2.0  1546808400
# ...           ...      ...     ...         ...
# 71226       71226  2502453     5.0  1548018000
# 71227       71227  1693213     2.0  1548018000
# 71228       71228  1891350     2.0  1548018000
# 71229       71229  2437172     2.0  1548018000
# 71230       71230   988236     2.0  1548018000
#
# [71231 rows x 4 columns]

# %%
test = pd.merge(test, features_test, on='id')

# %%
test
# Out:
#        Unnamed: 0_x       id  vas_id  buy_time_x  Unnamed: 0_y  buy_time_y  \
# 0                 0  3130519     2.0  1548018000       1871362  1536526800
# 1                 1  2000860     4.0  1548018000       2024591  1532293200
# 2                 2  1099444     2.0  1546808400       4041332  1541365200
# 3                 3  1343255     5.0  1547413200       1945062  1536526800
# 4                 4  1277040     2.0  1546808400       3503668  1532293200
# ...             ...      ...     ...         ...           ...         ...
# 73661         71226  2502453     5.0  1548018000        820229  1534712400
# 73662         71227  1693213     2.0  1548018000       3872196  1541970000
# 73663         71228  1891350     2.0  1548018000       3188331  1545598800
# 73664         71229  2437172     2.0  1548018000       1510984  1532293200
# 73665         71230   988236     2.0  1548018000       1449674  1535922000
#
#                 0           1           2           3  ...          243  \
# 0      -62.899971 -374.279112  -72.600786 -418.406798  ...  -970.373846
# 1      -96.799971  100.290888 -110.740786  140.903202  ...  -977.373846
# 2      -81.969971 -390.729112  -95.910786 -443.336798  ...  -977.373846
# 3      259.130029  -52.249112  245.189214 -104.856798  ...  -977.373846
# 4      331.170029  590.890888  317.229214  538.283202  ...  -651.373846
# ...           ...         ...         ...         ...  ...          ...
# 73661  -96.799971 -408.179112 -110.740786 -460.786798  ...  -977.373846
# 73662  -89.689971 -355.809112 -103.630786 -408.416798  ...  -977.373846
# 73663  -96.799971 -281.059112 -110.740786 -333.666798  ...  1640.626154
# 73664  115.060029  -87.339112  101.119214 -127.236798  ...  -977.373846
# 73665  -96.799971   68.510888 -110.740786   15.903202  ...  -976.373846
#
#                244        245        246         247         248       249  \
# 0      -613.770792 -25.996269 -37.630448 -258.747724  -25.832889 -0.694428
# 1      -613.770792 -25.996269 -37.630448 -254.747724  -25.832889 -0.694428
# 2      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 3      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 4      -612.770792   1.003731 -36.630448   38.252276  -12.832889 -0.694428
# ...            ...        ...        ...         ...         ...       ...
# 73661  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73662  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73663  1927.229208 -25.996269 -32.630448  -33.747724  -18.832889 -0.694428
# 73664  -613.770792 -25.996269 -37.630448 -280.747724  119.167111 -0.694428
# 73665  -613.770792 -25.996269 -31.630448 -265.747724   38.167111 -0.694428
#
#               250       251  252
# 0      -12.175933  -0.45614  0.0
# 1      -12.175933  -0.45614  0.0
# 2      -12.175933  -0.45614  1.0
# 3      -12.175933  -0.45614  1.0
# 4      -12.175933  12.54386  0.0
# ...           ...       ...  ...
# 73661  -12.175933  -0.45614  0.0
# 73662  -12.175933  -0.45614  0.0
# 73663  -10.175933  -0.45614  0.0
# 73664  132.824067  -0.45614  0.0
# 73665   51.824067  -0.45614  0.0
#
# [73666 rows x 259 columns]

# %%
test.isnull().sum()
# Out:
# Unnamed: 0_x    0
# id              0
# vas_id          0
# buy_time_x      0
# Unnamed: 0_y    0
#                ..
# 248             0
# 249             0
# 250             0
# 251             0
# 252             0
# Length: 259, dtype: int64

# %%
tmp = test.loc[test['id'].isin(dublicated.index)]

# %%
tmp
# Out:
#        Unnamed: 0_x       id  vas_id  buy_time_x  Unnamed: 0_y  buy_time_y  \
# 118             118  1759413     6.0  1547413200       1010540  1540155600
# 119             118  1759413     6.0  1547413200       4211678  1531688400
# 123             122  2502506     2.0  1547413200        254525  1543179600
# 124             122  2502506     2.0  1547413200       2465416  1535317200
# 139             137  3130584     2.0  1546808400        571842  1532898000
# ...             ...      ...     ...         ...           ...         ...
# 73608         71175   653078     5.0  1548018000       3195752  1541970000
# 73610         71177  4088260     2.0  1548018000       2355956  1531688400
# 73611         71177  4088260     2.0  1548018000       3169222  1534712400
# 73638         71204   248256     5.0  1548018000       1829273  1544389200
# 73639         71204   248256     5.0  1548018000       3343150  1542574800
#
#                 0           1           2           3  ...         243  \
# 118    -96.799971 -408.179112 -110.740786 -460.786798  ... -977.373846
# 119    -95.949971 -368.439112 -109.890786 -421.046798  ... -977.373846
# 123    -96.799971 -270.469112 -110.740786 -323.076798  ... -977.373846
# 124    184.510029  -93.569112  170.569214   61.443202  ... -715.373846
# 139    -96.799971 -103.099112 -110.740786  -92.146798  ... -876.373846
# ...           ...         ...         ...         ...  ...         ...
# 73608   90.320029  -77.609112   76.379214 -130.216798  ... -775.373846
# 73610  136.970029  -99.199112  127.269214 -142.486798  ... -977.373846
# 73611  -26.269971  148.080888  -40.210786  133.613202  ... -977.373846
# 73638  221.000029  -65.959112  207.059214 -118.566798  ...  850.626154
# 73639  -75.439971   97.520888  -89.380786   44.913202  ... -669.373846
#
#               244        245        246         247        248       249  \
# 118   -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 119   -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 123   -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 124   -351.770792 -25.996269 -37.630448 -222.747724 -16.832889 -0.694428
# 139   -587.770792 -24.996269 -36.630448 -203.747724 -14.832889 -0.694428
# ...           ...        ...        ...         ...        ...       ...
# 73608 -596.770792  -3.996269 -36.630448  -58.747724 -13.832889 -0.694428
# 73610 -613.770792 -25.996269 -37.630448 -298.747724 -25.832889 -0.694428
# 73611 -613.770792 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428
# 73638  -12.770792 -17.996269 -37.630448 -212.747724 -25.832889 -0.694428
# 73639 -613.770792 -24.996269 -37.630448 -261.747724 -25.832889 -0.694428
#
#              250      251  252
# 118   -12.175933 -0.45614  0.0
# 119   -12.175933 -0.45614  0.0
# 123   -12.175933 -0.45614  1.0
# 124    -3.175933 -0.45614  0.0
# 139    -1.175933 -0.45614  0.0
# ...          ...      ...  ...
# 73608 -11.175933 -0.45614  0.0
# 73610 -12.175933 -0.45614  0.0
# 73611 -12.175933 -0.45614  0.0
# 73638 -12.175933 -0.45614  1.0
# 73639 -12.175933 -0.45614  0.0
#
# [4870 rows x 259 columns]

# %%
tmp['delta'] = abs(tmp['buy_time_x'] - tmp['buy_time_y'])
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp.sort_values(by = ['Unnamed: 0_x', 'delta'], inplace=True)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp
# Out:
#        Unnamed: 0_x       id  vas_id  buy_time_x  Unnamed: 0_y  buy_time_y  \
# 118             118  1759413     6.0  1547413200       1010540  1540155600
# 119             118  1759413     6.0  1547413200       4211678  1531688400
# 123             122  2502506     2.0  1547413200        254525  1543179600
# 124             122  2502506     2.0  1547413200       2465416  1535317200
# 139             137  3130584     2.0  1546808400        571842  1532898000
# ...             ...      ...     ...         ...           ...         ...
# 73608         71175   653078     5.0  1548018000       3195752  1541970000
# 73611         71177  4088260     2.0  1548018000       3169222  1534712400
# 73610         71177  4088260     2.0  1548018000       2355956  1531688400
# 73638         71204   248256     5.0  1548018000       1829273  1544389200
# 73639         71204   248256     5.0  1548018000       3343150  1542574800
#
#                 0           1           2           3  ...         244  \
# 118    -96.799971 -408.179112 -110.740786 -460.786798  ... -613.770792
# 119    -95.949971 -368.439112 -109.890786 -421.046798  ... -613.770792
# 123    -96.799971 -270.469112 -110.740786 -323.076798  ... -613.770792
# 124    184.510029  -93.569112  170.569214   61.443202  ... -351.770792
# 139    -96.799971 -103.099112 -110.740786  -92.146798  ... -587.770792
# ...           ...         ...         ...         ...  ...         ...
# 73608   90.320029  -77.609112   76.379214 -130.216798  ... -596.770792
# 73611  -26.269971  148.080888  -40.210786  133.613202  ... -613.770792
# 73610  136.970029  -99.199112  127.269214 -142.486798  ... -613.770792
# 73638  221.000029  -65.959112  207.059214 -118.566798  ...  -12.770792
# 73639  -75.439971   97.520888  -89.380786   44.913202  ... -613.770792
#
#              245        246         247        248       249        250  \
# 118   -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 119   -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 123   -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 124   -25.996269 -37.630448 -222.747724 -16.832889 -0.694428  -3.175933
# 139   -24.996269 -36.630448 -203.747724 -14.832889 -0.694428  -1.175933
# ...          ...        ...         ...        ...       ...        ...
# 73608  -3.996269 -36.630448  -58.747724 -13.832889 -0.694428 -11.175933
# 73611 -25.996269 -37.630448 -306.747724 -25.832889 -0.694428 -12.175933
# 73610 -25.996269 -37.630448 -298.747724 -25.832889 -0.694428 -12.175933
# 73638 -17.996269 -37.630448 -212.747724 -25.832889 -0.694428 -12.175933
# 73639 -24.996269 -37.630448 -261.747724 -25.832889 -0.694428 -12.175933
#
#            251  252     delta
# 118   -0.45614  0.0   7257600
# 119   -0.45614  0.0  15724800
# 123   -0.45614  1.0   4233600
# 124   -0.45614  0.0  12096000
# 139   -0.45614  0.0  13910400
# ...        ...  ...       ...
# 73608 -0.45614  0.0   6048000
# 73611 -0.45614  0.0  13305600
# 73610 -0.45614  0.0  16329600
# 73638 -0.45614  1.0   3628800
# 73639 -0.45614  0.0   5443200
#
# [4870 rows x 260 columns]

# %%
del_idx = tmp['Unnamed: 0_x'].duplicated()

# %%
del_idx = del_idx[del_idx.values == True]

# %%
del_idx
# Out:
# 119      True
# 124      True
# 140      True
# 279      True
# 331      True
#          ...
# 73546    True
# 73558    True
# 73608    True
# 73610    True
# 73639    True
# Name: Unnamed: 0_x, Length: 2435, dtype: bool

# %%
test.drop(del_idx.index, axis=0, inplace=True)

# %%
test
# Out:
#        Unnamed: 0_x       id  vas_id  buy_time_x  Unnamed: 0_y  buy_time_y  \
# 0                 0  3130519     2.0  1548018000       1871362  1536526800
# 1                 1  2000860     4.0  1548018000       2024591  1532293200
# 2                 2  1099444     2.0  1546808400       4041332  1541365200
# 3                 3  1343255     5.0  1547413200       1945062  1536526800
# 4                 4  1277040     2.0  1546808400       3503668  1532293200
# ...             ...      ...     ...         ...           ...         ...
# 73661         71226  2502453     5.0  1548018000        820229  1534712400
# 73662         71227  1693213     2.0  1548018000       3872196  1541970000
# 73663         71228  1891350     2.0  1548018000       3188331  1545598800
# 73664         71229  2437172     2.0  1548018000       1510984  1532293200
# 73665         71230   988236     2.0  1548018000       1449674  1535922000
#
#                 0           1           2           3  ...          243  \
# 0      -62.899971 -374.279112  -72.600786 -418.406798  ...  -970.373846
# 1      -96.799971  100.290888 -110.740786  140.903202  ...  -977.373846
# 2      -81.969971 -390.729112  -95.910786 -443.336798  ...  -977.373846
# 3      259.130029  -52.249112  245.189214 -104.856798  ...  -977.373846
# 4      331.170029  590.890888  317.229214  538.283202  ...  -651.373846
# ...           ...         ...         ...         ...  ...          ...
# 73661  -96.799971 -408.179112 -110.740786 -460.786798  ...  -977.373846
# 73662  -89.689971 -355.809112 -103.630786 -408.416798  ...  -977.373846
# 73663  -96.799971 -281.059112 -110.740786 -333.666798  ...  1640.626154
# 73664  115.060029  -87.339112  101.119214 -127.236798  ...  -977.373846
# 73665  -96.799971   68.510888 -110.740786   15.903202  ...  -976.373846
#
#                244        245        246         247         248       249  \
# 0      -613.770792 -25.996269 -37.630448 -258.747724  -25.832889 -0.694428
# 1      -613.770792 -25.996269 -37.630448 -254.747724  -25.832889 -0.694428
# 2      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 3      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 4      -612.770792   1.003731 -36.630448   38.252276  -12.832889 -0.694428
# ...            ...        ...        ...         ...         ...       ...
# 73661  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73662  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73663  1927.229208 -25.996269 -32.630448  -33.747724  -18.832889 -0.694428
# 73664  -613.770792 -25.996269 -37.630448 -280.747724  119.167111 -0.694428
# 73665  -613.770792 -25.996269 -31.630448 -265.747724   38.167111 -0.694428
#
#               250       251  252
# 0      -12.175933  -0.45614  0.0
# 1      -12.175933  -0.45614  0.0
# 2      -12.175933  -0.45614  1.0
# 3      -12.175933  -0.45614  1.0
# 4      -12.175933  12.54386  0.0
# ...           ...       ...  ...
# 73661  -12.175933  -0.45614  0.0
# 73662  -12.175933  -0.45614  0.0
# 73663  -10.175933  -0.45614  0.0
# 73664  132.824067  -0.45614  0.0
# 73665   51.824067  -0.45614  0.0
#
# [71231 rows x 259 columns]

# %% [markdown]
# Итого количество строк равно количеству строк в исходном test. Если для данного пользователя в features_test было несколько записей, учитываем только ту, которая по времени была ближе к той, которая в test

# %%
test.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'buy_time_y'], axis=1, inplace=True)

# %%
test
# Out:
#             id  vas_id  buy_time_x           0           1           2  \
# 0      3130519     2.0  1548018000  -62.899971 -374.279112  -72.600786
# 1      2000860     4.0  1548018000  -96.799971  100.290888 -110.740786
# 2      1099444     2.0  1546808400  -81.969971 -390.729112  -95.910786
# 3      1343255     5.0  1547413200  259.130029  -52.249112  245.189214
# 4      1277040     2.0  1546808400  331.170029  590.890888  317.229214
# ...        ...     ...         ...         ...         ...         ...
# 73661  2502453     5.0  1548018000  -96.799971 -408.179112 -110.740786
# 73662  1693213     2.0  1548018000  -89.689971 -355.809112 -103.630786
# 73663  1891350     2.0  1548018000  -96.799971 -281.059112 -110.740786
# 73664  2437172     2.0  1548018000  115.060029  -87.339112  101.119214
# 73665   988236     2.0  1548018000  -96.799971   68.510888 -110.740786
#
#                 3           4          5         6  ...          243  \
# 0     -418.406798  -78.018246 -439.51179  17.81382  ...  -970.373846
# 1      140.903202 -116.158246  119.79821 -16.08618  ...  -977.373846
# 2     -443.336798 -101.328246 -464.44179 -16.08618  ...  -977.373846
# 3     -104.856798  239.771754 -125.96179 -16.08618  ...  -977.373846
# 4      538.283202  311.811754  522.25821 -16.08618  ...  -651.373846
# ...           ...         ...        ...       ...  ...          ...
# 73661 -460.786798 -116.158246 -481.89179 -16.08618  ...  -977.373846
# 73662 -408.416798 -109.048246 -429.52179 -16.08618  ...  -977.373846
# 73663 -333.666798 -116.158246 -354.77179 -16.08618  ...  1640.626154
# 73664 -127.236798   95.701754 -148.34179 -16.08618  ...  -977.373846
# 73665   15.903202 -116.158246   83.76821 -16.08618  ...  -976.373846
#
#                244        245        246         247         248       249  \
# 0      -613.770792 -25.996269 -37.630448 -258.747724  -25.832889 -0.694428
# 1      -613.770792 -25.996269 -37.630448 -254.747724  -25.832889 -0.694428
# 2      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 3      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 4      -612.770792   1.003731 -36.630448   38.252276  -12.832889 -0.694428
# ...            ...        ...        ...         ...         ...       ...
# 73661  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73662  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 73663  1927.229208 -25.996269 -32.630448  -33.747724  -18.832889 -0.694428
# 73664  -613.770792 -25.996269 -37.630448 -280.747724  119.167111 -0.694428
# 73665  -613.770792 -25.996269 -31.630448 -265.747724   38.167111 -0.694428
#
#               250       251  252
# 0      -12.175933  -0.45614  0.0
# 1      -12.175933  -0.45614  0.0
# 2      -12.175933  -0.45614  1.0
# 3      -12.175933  -0.45614  1.0
# 4      -12.175933  12.54386  0.0
# ...           ...       ...  ...
# 73661  -12.175933  -0.45614  0.0
# 73662  -12.175933  -0.45614  0.0
# 73663  -10.175933  -0.45614  0.0
# 73664  132.824067  -0.45614  0.0
# 73665   51.824067  -0.45614  0.0
#
# [71231 rows x 256 columns]

# %% [markdown]
# ### Сохраняем полученные train и test

# %%
train.to_csv('train_new.csv')

# %%
test.to_csv('test_new.csv')

# %% [markdown]
# ## Baseline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Разделим признаки и целевую переменную

# %%
X = pd.read_csv('train_new.csv')

# %%
X
# Out:
#         Unnamed: 0       id  vas_id  buy_time_x  target           0  \
# 0                0   540968     8.0  1537131600     0.0  -31.559971
# 1                1  1454121     4.0  1531688400     0.0  547.270029
# 2                2  2458816     1.0  1534107600     0.0  -92.139971
# 3                3  3535012     5.0  1535922000     0.0   54.880029
# 4                4  1693214     1.0  1535922000     0.0   45.160029
# ...            ...      ...     ...         ...     ...         ...
# 831648      860047  3812226     2.0  1546203600     0.0   29.750029
# 831649      860048  2480469     2.0  1546203600     0.0  -89.179971
# 831650      860049   158236     2.0  1546203600     0.0  -96.799971
# 831651      860050  1825525     2.0  1546203600     0.0  -96.799971
# 831652      860051  3022610     2.0  1546203600     0.0  -49.339971
#
#                  1           2           3           4  ...          243  \
# 0       327.360888  -45.500786  274.753202  -50.918246  ...  -845.373846
# 1       238.430888  533.329214  274.803202  527.911754  ...  -972.373846
# 2       -95.469112 -106.080786 -139.596798 -111.498246  ...  -977.373846
# 3        12.970888   54.079214   -9.116798   48.661754  ...  -977.373846
# 4       295.240888   64.679214  344.283202   59.261754  ...  -965.373846
# ...            ...         ...         ...         ...  ...          ...
# 831648    6.200888   24.279214  -37.936798   18.861754  ...  -977.373846
# 831649  -56.499112 -103.120786 -109.106798 -108.538246  ...   -66.373846
# 831650   62.140888 -110.740786    9.533202 -116.158246  ...  -683.373846
# 831651  -81.919112 -110.740786 -128.596798 -116.158246  ...  1018.626154
# 831652 -218.339112   73.139214  145.093202   67.721754  ...  -977.373846
#
#                 244        245        246          247         248       249  \
# 0       -613.770792 -20.996269 -37.630448   -28.747724    4.167111  7.305572
# 1       -613.770792 -25.996269 -19.630448  -278.747724  -24.832889 -0.694428
# 2       -613.770792 -25.996269 -37.630448  -304.747724  -25.832889 -0.694428
# 3       -613.770792 -25.996269 -18.630448  -133.747724  -14.832889 -0.694428
# 4       -612.770792 -22.996269 -32.630448  -127.747724   -4.832889 -0.694428
# ...             ...        ...        ...          ...         ...       ...
# 831648  -613.770792 -25.996269 -37.630448  -306.747724  -25.832889 -0.694428
# 831649  -321.770792 -25.996269  62.369552  1167.252276   41.167111 -0.694428
# 831650  -470.770792 -25.996269 -37.630448    99.252276  178.167111 -0.694428
# 831651  1367.229208 -24.996269 -35.630448  -237.747724  -21.832889 -0.694428
# 831652  -613.770792 -25.996269 -37.630448  -303.747724  -25.832889 -0.694428
#
#                250       251  252
# 0       -12.175933  21.54386  0.0
# 1       -11.175933  -0.45614  0.0
# 2       -12.175933  -0.45614  0.0
# 3        -1.175933  -0.45614  0.0
# 4       -12.175933  -0.45614  0.0
# ...            ...       ...  ...
# 831648  -12.175933  -0.45614  0.0
# 831649   54.824067  -0.45614  0.0
# 831650  191.824067  -0.45614  0.0
# 831651   -8.175933  -0.45614  1.0
# 831652  -12.175933  -0.45614  0.0
#
# [831653 rows x 258 columns]

# %%
X_test = pd.read_csv('test_new.csv')

# %%
X_test
# Out:
#        Unnamed: 0       id  vas_id  buy_time_x           0           1  \
# 0               0  3130519     2.0  1548018000  -62.899971 -374.279112
# 1               1  2000860     4.0  1548018000  -96.799971  100.290888
# 2               2  1099444     2.0  1546808400  -81.969971 -390.729112
# 3               3  1343255     5.0  1547413200  259.130029  -52.249112
# 4               4  1277040     2.0  1546808400  331.170029  590.890888
# ...           ...      ...     ...         ...         ...         ...
# 71226       73661  2502453     5.0  1548018000  -96.799971 -408.179112
# 71227       73662  1693213     2.0  1548018000  -89.689971 -355.809112
# 71228       73663  1891350     2.0  1548018000  -96.799971 -281.059112
# 71229       73664  2437172     2.0  1548018000  115.060029  -87.339112
# 71230       73665   988236     2.0  1548018000  -96.799971   68.510888
#
#                 2           3           4          5  ...          243  \
# 0      -72.600786 -418.406798  -78.018246 -439.51179  ...  -970.373846
# 1     -110.740786  140.903202 -116.158246  119.79821  ...  -977.373846
# 2      -95.910786 -443.336798 -101.328246 -464.44179  ...  -977.373846
# 3      245.189214 -104.856798  239.771754 -125.96179  ...  -977.373846
# 4      317.229214  538.283202  311.811754  522.25821  ...  -651.373846
# ...           ...         ...         ...        ...  ...          ...
# 71226 -110.740786 -460.786798 -116.158246 -481.89179  ...  -977.373846
# 71227 -103.630786 -408.416798 -109.048246 -429.52179  ...  -977.373846
# 71228 -110.740786 -333.666798 -116.158246 -354.77179  ...  1640.626154
# 71229  101.119214 -127.236798   95.701754 -148.34179  ...  -977.373846
# 71230 -110.740786   15.903202 -116.158246   83.76821  ...  -976.373846
#
#                244        245        246         247         248       249  \
# 0      -613.770792 -25.996269 -37.630448 -258.747724  -25.832889 -0.694428
# 1      -613.770792 -25.996269 -37.630448 -254.747724  -25.832889 -0.694428
# 2      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 3      -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 4      -612.770792   1.003731 -36.630448   38.252276  -12.832889 -0.694428
# ...            ...        ...        ...         ...         ...       ...
# 71226  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 71227  -613.770792 -25.996269 -37.630448 -306.747724  -25.832889 -0.694428
# 71228  1927.229208 -25.996269 -32.630448  -33.747724  -18.832889 -0.694428
# 71229  -613.770792 -25.996269 -37.630448 -280.747724  119.167111 -0.694428
# 71230  -613.770792 -25.996269 -31.630448 -265.747724   38.167111 -0.694428
#
#               250       251  252
# 0      -12.175933  -0.45614  0.0
# 1      -12.175933  -0.45614  0.0
# 2      -12.175933  -0.45614  1.0
# 3      -12.175933  -0.45614  1.0
# 4      -12.175933  12.54386  0.0
# ...           ...       ...  ...
# 71226  -12.175933  -0.45614  0.0
# 71227  -12.175933  -0.45614  0.0
# 71228  -10.175933  -0.45614  0.0
# 71229  132.824067  -0.45614  0.0
# 71230   51.824067  -0.45614  0.0
#
# [71231 rows x 257 columns]

# %%
y = X.target

# %%
X.drop(['Unnamed: 0', 'target'], axis=1, inplace=True)

# %%
#print("ID уникален? ", X.index.is_unique)
#print("Есть ли дубли в строках?", X.duplicated().sum())
#print("Сколько процент признаков могут принимать null-значениями? %d%%" % float((X.isnull().sum() > 0).sum()/X.shape[1]*100))

# %%
X_test.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
X['vas_id'] = X['vas_id'].astype('int')

# %%
X_test['vas_id'] = X_test['vas_id'].astype('int')

# %% [markdown]
# ### Разделяем на train и valid

# %%
dis = y.value_counts()
sns.barplot(x=dis.index, y=dis.values)

# %%
from sklearn.model_selection import train_test_split

# Зафиксируем значение random_state для воспроизводимости результатов.
RANDOM_STATE = 888

train_idx, valid_idx = train_test_split(X.index, test_size=0.25, random_state=RANDOM_STATE)

y_train, y_valid = y.loc[train_idx], y.loc[valid_idx]
X_train, X_valid = X.loc[train_idx], X.loc[valid_idx]

print("Train")
print(y.loc[train_idx].value_counts()/train_idx.shape[0])
print()
print("Test")
print(y.loc[valid_idx].value_counts()/valid_idx.shape[0])
# Out:
# Train
# 0.0    0.927521
# 1.0    0.072479
# Name: target, dtype: float64
#
# Test
# 0.0    0.927961
# 1.0    0.072039
# Name: target, dtype: float64

# %% [markdown]
# ### Логистическая регрессия

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(random_state=RANDOM_STATE, n_jobs=-1)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate

kfold_cv = KFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

def run_cv(estimator, cv, X, y, scoring='roc_auc', model_name=""):
    cv_res = cross_validate(estimator, X, y, cv=cv, scoring=scoring, n_jobs=-1)
    
    print("%s: %s = %0.2f (+/- %0.2f)" % (model_name,
                                         scoring,
                                         cv_res['test_score'].mean(),
                                         cv_res['test_score'].std() * 2))

# %%
run_cv(log_reg, kfold_cv, X_train, y_train, model_name="Baseline");
# Out:
# Baseline: roc_auc = 0.56 (+/- 0.00)

# %% [markdown]
# ### Графики и метрики baseline модели на тесте

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=-1, penalty='l2',
#                    random_state=888, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_reg_pred = log_reg.predict_proba(X_valid)[:,1]

# %% [markdown]
# #### Распределение предсказаний baseline модели

# %%
plt.title("Baseline: распределение предсказаний модели")
plt.hist(log_reg_pred[~y_valid.astype(bool)], bins=100, color='r', alpha=0.7);
plt.hist(log_reg_pred[y_valid.astype(bool)], bins=100, color='b', alpha=0.7);

# %% [markdown]
# #### Roc и PR Кривые

# %%
from sklearn.metrics import precision_recall_curve, roc_curve, auc

fpr, tpr, roc_thresholds = roc_curve(y_valid, log_reg_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, log_reg_pred)

# %%
def plot_roc_curve(fpr, tpr, model_name="", color=None):
    plt.plot(fpr, tpr, label='%s: ROC curve (area = %0.2f)' %
             (model_name, auc(fpr, tpr)), color=color)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0.0, 1.0, 0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('%s: Receiver operating characteristic curve' % model_name)
    plt.legend(loc="lower right")

plt.figure(figsize=(7, 7))
plot_roc_curve(fpr, tpr, "Baseline", color='r')
print("Baseline: AUC_ROC = %.3f" % auc(fpr, tpr))
# Out:
# Baseline: AUC_ROC = 0.567

# %%
def plot_precision_recall_curve(recall, precision, model_name="", color=None):
    plt.plot(recall, precision, label='%s: Precision-Recall curve (area = %0.2f)' %
             (model_name, auc(recall, precision)), color=color)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title("%s: Precision-Recall curve" % model_name)
    plt.axis([0.0, 1.0, 0.0, 1.05])
    plt.legend(loc="lower left")

plt.figure(figsize=(7, 7))
    
plot_precision_recall_curve(recall, precision, "Baseline", color='r')
print("Baseline: AUC_PR = %.3f" % auc(recall, precision))
# Out:
# Baseline: AUC_PR = 0.086

# %% [markdown]
# #### Матрица смежности

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          model_name="",
                          normalize=False,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest',  cmap=cmap)
    
    plt.grid(False)
    plt.title('%s: confusion matrix' % model_name)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# TN                FP(Type I error)
# 
# FN(Type II error)  TP

cm = confusion_matrix(y_valid, log_reg_pred > 0.5)
plot_confusion_matrix(cm, classes=["0", "1"], model_name="Baseline");
# Out:
# Confusion matrix, without normalization
# [[192936      0]
#  [ 14978      0]]

# %% [markdown]
# #### classification_report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_valid, log_reg_pred > 0.5))
# Out:
# d:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96    192936
#          1.0       0.00      0.00      0.00     14978
#
#     accuracy                           0.93    207914
#    macro avg       0.46      0.50      0.48    207914
# weighted avg       0.86      0.93      0.89    207914

# %% [markdown]
# ## Определение типа признаков

# %%
X_nunique = X.nunique()

# %%
X_nunique
# Out:
# id            806613
# vas_id             8
# buy_time_x        26
# 0              46162
# 1             112909
#                ...
# 248             2342
# 249              265
# 250             1599
# 251              248
# 252               30
# Length: 256, dtype: int64

# %%
plt.title("Распределение уникальных значений признаков");
X_nunique.hist(bins=100, figsize=(10, 5));

# %%
f_all = set(X_nunique.index.tolist())
len(f_all)
# Out:
# 256

# %% [markdown]
# #### константные признаки

# %%
f_const = set(X_nunique[X_nunique == 1].index.tolist())
len(f_const)
# Out:
# 5

# %%
f_const
# Out:
# {'139', '203', '75', '81', '85'}

# %% [markdown]
# #### вещественные признаки

# %%
f_numeric = (X.fillna(0).astype(int).sum() - X.fillna(0).sum()).abs()
f_numeric = set(f_numeric[f_numeric > 0].index.tolist())
len(f_numeric)
# Out:
# 247

# %%
f_other = f_all - (f_numeric | f_const)
len(f_other)
# Out:
# 4

# %% [markdown]
# #### бинарные

# %%
f_binary = set(X.loc[:, f_other].columns[(
                      (X.loc[:, f_other].max() == 1) & \
                      (X.loc[:, f_other].min() == 0) & \
                      (X.loc[:, f_other].isnull().sum() == 0))])
len(f_binary)
# Out:
# 0

# %%
f_other = f_other - f_binary
len(f_other)
# Out:
# 4

# %% [markdown]
# #### целочисленные признаки

# %%
f_int = (X.loc[:, f_other].astype(int).sum() - X.loc[:, f_other].sum()).abs()
f_int = set(f_int[f_int == 0].index.tolist())
len(f_int)
# Out:
# 4

# %%
X[f_int]
# Out:
#         vas_id  252       id  buy_time_x
# 0            8  0.0   540968  1537131600
# 1            4  0.0  1454121  1531688400
# 2            1  0.0  2458816  1534107600
# 3            5  0.0  3535012  1535922000
# 4            1  0.0  1693214  1535922000
# ...        ...  ...      ...         ...
# 831648       2  0.0  3812226  1546203600
# 831649       2  0.0  2480469  1546203600
# 831650       2  0.0   158236  1546203600
# 831651       2  1.0  1825525  1546203600
# 831652       2  0.0  3022610  1546203600
#
# [831653 rows x 4 columns]

# %%
f_other == f_int
# Out:
# True

# %%
X['vas_id'].value_counts()
# Out:
# 1    310175
# 2    249505
# 5     94085
# 4     85756
# 6     57878
# 7     15432
# 8     13350
# 9      5472
# Name: vas_id, dtype: int64

# %%
f_categorical = set(X_nunique.loc[f_other][X_nunique.loc[f_other] <= 10].index.tolist())

# %%
f_categorical
# Out:
# {'vas_id'}

# %%
f_other = f_other - f_categorical
len(f_other)
# Out:
# 3

# %%
f_numeric = f_numeric | f_other

# %%
f_other = f_other - f_numeric
len(f_other)
# Out:
# 0

# %%
assert(X_nunique.shape[0] == len(f_const) + len(f_binary) + len(f_numeric) + len(f_categorical))

# %%
print('f_all:', X.shape[1])
print()
print('f_const:', len(f_const))
print('f_binary:', len(f_binary))
print('f_categorical:', len(f_categorical))
print('f_numeric:', len(f_numeric))

f_ok = list(f_binary | f_categorical | f_numeric)
f_binary, f_categorical, f_numeric = list(f_binary), list(f_categorical), list(f_numeric)
# Out:
# f_all: 256
#
# f_const: 5
# f_binary: 0
# f_categorical: 1
# f_numeric: 250

# %%
len(f_ok)
# Out:
# 251

# %% [markdown]
# ## Пайплайны

# %% [markdown]
# ### Column selector

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class ColumnSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        assert isinstance(X, pd.DataFrame)

        try:
            return X[self.columns]
        except KeyError:
            cols_error = list(set(self.columns) - set(X.columns))
            raise KeyError("DataFrame не содердит следующие колонки: %s" % cols_error)

# %% [markdown]
# ### Пайплайн обработки признаков

# %%
from sklearn.pipeline import FeatureUnion, make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
f_prep_pipeline = make_pipeline(
    ColumnSelector(columns=f_ok),
    FeatureUnion(transformer_list=[
        ("numeric_features", make_pipeline(
            ColumnSelector(f_numeric),
            #SimpleImputer(strategy="mean"),
            StandardScaler()
        )),
        ("categorical_features", make_pipeline(
            ColumnSelector(f_categorical),
            #SimpleImputer(strategy="most_frequent"),
            OneHotEncoder(handle_unknown='ignore')
        ))
    ])
)

# %%
f_prep_pipeline.steps
# Out:
# [('columnselector',
#   ColumnSelector(columns=['42', '172', '202', '38', '86', '211', '187', '160',
#                           '241', 'vas_id', '218', '128', '246', '117', '60', '19',
#                           '184', '3', '145', '135', '214', '67', '77', '166',
#                           '250', '224', '112', '165', '37', '4', ...])),
#  ('featureunion',
#   FeatureUnion(n_jobs=None,
#                transformer_list=[('numeric_features',
#                                   Pipeline(memory=None,
#                                            steps=[('columnselector',
#                                                    ColumnSelector(columns=['42',
#                                                                            '172',
#                                                                            '202',
#                                                                            '38',
#                                                                            '86',
#                                                                            '211',
#                                                                            '187',
#                                                                            '160',
#                                                                            '241',
#                                                                            '218',
#                                                                            '128',
#                                                                            '246',
#                                                                            '117',
#                                                                            '60',
#                                                                            '19',
#                                                                            '184',
#                                                                            '3',
#                                                                            '145',
#                                                                            '135',
#                                                                            '214',
#                                                                            '67',
#                                                                            '77',
#                                                                            '166',
#                                                                            '250',
#                                                                            '224',
#                                                                            '112',
#                                                                            '165',
#                                                                            '37',
#                                                                            '4',
#                                                                            '78', ...])),
#                                                   ('standardscaler',
#                                                    StandardScaler(copy=True,
#                                                                   with_mean=True,
#                                                                   with_std=True))],
#                                            verbose=False)),
#                                  ('categorical_features',
#                                   Pipeline(memory=None,
#                                            steps=[('columnselector',
#                                                    ColumnSelector(columns=['vas_id'])),
#                                                   ('onehotencoder',
#                                                    OneHotEncoder(categories='auto',
#                                                                  drop=None,
#                                                                  dtype=<class 'numpy.float64'>,
#                                                                  handle_unknown='ignore',
#                                                                  sparse=True))],
#                                            verbose=False))],
#                transformer_weights=None, verbose=False))]

# %%
X_valid.shape[1]
# Out:
# 256

# %%
f_prep_pipeline.fit(X_train)

n_features = f_prep_pipeline.transform(X_valid).shape[1]
n_features
# Out:
# 257

# %% [markdown]
# ### Greedsearch для пайплайнов

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate

kfold_cv = KFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

# %%
lg_pipe = make_pipeline(
    f_prep_pipeline,
    LogisticRegression(random_state=RANDOM_STATE)
)

# %%
from sklearn.model_selection import GridSearchCV

# %%
def run_grid_search(estimator, X, y, params_grid, cv, scoring='roc_auc'):
    gsc = GridSearchCV(estimator, params_grid, scoring=scoring, cv=cv, n_jobs=-1)

    gsc.fit(X, y)
    print("Best %s score: %.2f" % (scoring, gsc.best_score_))
    print()
    print("Best parameters set found on development set:")
    print()
    print(gsc.best_params_)
    print()
    print("Grid scores on development set:")
    print()

    for i, params in enumerate(gsc.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (gsc.cv_results_['mean_test_score'][i], gsc.cv_results_['std_test_score'][i] * 2, params))

    print()
    
    return gsc

# %%
param_grid = {
    "logisticregression__penalty": ['l1', 'l2'],
    "logisticregression__C": [0.01, 0.1, 5.0]
}

lg_gsc = run_grid_search(lg_pipe, X_train, y_train, param_grid, kfold_cv)
# Out:
# d:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Best roc_auc score: 0.86
#
# Best parameters set found on development set:
#
# {'logisticregression__C': 0.1, 'logisticregression__penalty': 'l2'}
#
# Grid scores on development set:
#
# nan (+/-nan) for {'logisticregression__C': 0.01, 'logisticregression__penalty': 'l1'}
# 0.859 (+/-0.001) for {'logisticregression__C': 0.01, 'logisticregression__penalty': 'l2'}
# nan (+/-nan) for {'logisticregression__C': 0.1, 'logisticregression__penalty': 'l1'}
# 0.860 (+/-0.001) for {'logisticregression__C': 0.1, 'logisticregression__penalty': 'l2'}
# nan (+/-nan) for {'logisticregression__C': 5.0, 'logisticregression__penalty': 'l1'}
# 0.860 (+/-0.001) for {'logisticregression__C': 5.0, 'logisticregression__penalty': 'l2'}

# %% [markdown]
# ## LogReg с использованием пайплайнов

# %%
# С = 0.1

# %%
lg_pipe_2 = make_pipeline(
    f_prep_pipeline,
    LogisticRegression(random_state=RANDOM_STATE, C = 0.1, n_jobs=-1)
)

# %%
lg_pipe_2.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('pipeline',
#                  Pipeline(memory=None,
#                           steps=[('columnselector',
#                                   ColumnSelector(columns=['42', '172', '202',
#                                                           '38', '86', '211',
#                                                           '187', '160', '241',
#                                                           'vas_id', '218',
#                                                           '128', '246', '117',
#                                                           '60', '19', '184',
#                                                           '3', '145', '135',
#                                                           '214', '67', '77',
#                                                           '166', '250', '224',
#                                                           '112', '165', '37',
#                                                           '4', ...])),
#                                  ('featureunion',
#                                   FeatureUnion(n_jobs=None,
#                                                transformer_list=[('n...
#                                                                                                  sparse=True))],
#                                                                            verbose=False))],
#                                                transformer_weights=None,
#                                                verbose=False))],
#                           verbose=False)),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=-1, penalty='l2',
#                                     random_state=888, solver='lbfgs',
#                                     tol=0.0001, verbose=0, warm_start=False))],
#          verbose=False)

# %%
log_reg_2_pred = lg_pipe_2.predict_proba(X_valid)[:,1]

# %%
from sklearn.metrics import precision_recall_curve, roc_curve, auc

fpr, tpr, roc_thresholds = roc_curve(y_valid, log_reg_2_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, log_reg_2_pred)

# %%
plt.figure(figsize=(7, 7))
plot_roc_curve(fpr, tpr, "LogReg+Pipe", color='r')
print("LogReg+Pipe: AUC_ROC = %.3f" % auc(fpr, tpr))
# Out:
# LogReg+Pipe: AUC_ROC = 0.872

# %%
plt.figure(figsize=(7, 7))
    
plot_precision_recall_curve(recall, precision, "LogReg+Pipe", color='r')
print("LogReg+Pipe: AUC_PR = %.3f" % auc(recall, precision))
# Out:
# LogReg+Pipe: AUC_PR = 0.374

# %%
# TN                FP(Type I error)
# 
# FN(Type II error)  TP

cm = confusion_matrix(y_valid, log_reg_2_pred > 0.5)
plot_confusion_matrix(cm, classes=["0", "1"], model_name="Baseline");
# Out:
# Confusion matrix, without normalization
# [[191240   1696]
#  [ 13535   1443]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_valid, log_reg_2_pred > 0.34))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.96    192936
#          1.0       0.44      0.48      0.46     14978
#
#     accuracy                           0.92    207914
#    macro avg       0.70      0.72      0.71    207914
# weighted avg       0.92      0.92      0.92    207914

# %% [markdown]
# ## CatBoost

# %%
import catboost

# %%
kfold_cv = KFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

# %%
model_catb = catboost.CatBoostClassifier(cat_features=['id', 'vas_id'],
                                      silent=True, random_state=21)

# %%
model_catb.get_params()
# Out:
# {'silent': True, 'random_state': 21, 'cat_features': ['id', 'vas_id']}

# %%
param_grid = {
    "depth": [3],
    "iterations": [300],
    'l2_leaf_reg': [5, 15, 25]
}

# %%
lg_gsc = run_grid_search(model_catb, X_train, y_train, param_grid, kfold_cv)
# Out:
# Best roc_auc score: 0.89
#
# Best parameters set found on development set:
#
# {'depth': 3, 'iterations': 300, 'l2_leaf_reg': 15}
#
# Grid scores on development set:
#
# 0.888 (+/-0.004) for {'depth': 3, 'iterations': 300, 'l2_leaf_reg': 5}
# 0.889 (+/-0.003) for {'depth': 3, 'iterations': 300, 'l2_leaf_reg': 15}
# 0.888 (+/-0.004) for {'depth': 3, 'iterations': 300, 'l2_leaf_reg': 25}

# %% [markdown]
# ## Построение наилучшей модели

# %%
model_catb = catboost.CatBoostClassifier(n_estimators=200, max_depth=4, l2_leaf_reg =15, cat_features=['id', 'vas_id'],
                                      silent=True, random_state=21)

# %%
model_catb.fit(X_train, y_train)

# %%
catb_pred = model_catb.predict_proba(X_valid)[:,1]

# %%
fpr, tpr, roc_thresholds = roc_curve(y_valid, catb_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, catb_pred)

# %%
plt.figure(figsize=(7, 7))
plot_roc_curve(fpr, tpr, "CatBoost", color='r')
print("CatBoost: AUC_ROC = %.3f" % auc(fpr, tpr))
# Out:
# CatBoost: AUC_ROC = 0.950

# %%
plt.figure(figsize=(7, 7))
    
plot_precision_recall_curve(recall, precision, "CatBoost", color='r')
print("CatBoost: AUC_PR = %.3f" % auc(recall, precision))
# Out:
# CatBoost: AUC_PR = 0.703

# %%
# TN                FP(Type I error)
# 
# FN(Type II error)  TP

cm = confusion_matrix(y_valid, catb_pred > 0.5)
plot_confusion_matrix(cm, classes=["0", "1"], model_name="Baseline");
# Out:
# Confusion matrix, without normalization
# [[192535    401]
#  [ 10060   4918]]

# %%
print(classification_report(y_valid, catb_pred > 0.38))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97    192936
#          1.0       0.64      0.54      0.58     14978
#
#     accuracy                           0.94    207914
#    macro avg       0.80      0.76      0.78    207914
# weighted avg       0.94      0.94      0.94    207914

# %% [markdown]
# ## Сравнение моделей

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

f.set_figheight(18)
f.set_figwidth(10)

ax1 = plt.subplot(211)
ax1.set_title('ROC')
ax1.set_xlabel('TPR')
ax1.set_ylabel('FPR')


ax2 = plt.subplot(212)
ax2.set_title('PR')
ax2.set_xlabel('Recall')
ax2.set_ylabel('Precision')

ax1.plot([0, 1], [0, 1], 'k--')

fpr, tpr, roc_thresholds = roc_curve(y_valid, log_reg_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, log_reg_pred)
ax1.plot(fpr, tpr, label='LogReg', color='b')
ax2.plot(recall, precision, label='LogReg', color='b')
print("LogReg: AUC_PR = %.3f" % auc(recall, precision))
print("LogReg: AUC_ROC = %.3f" % auc(fpr, tpr))


fpr, tpr, roc_thresholds = roc_curve(y_valid, log_reg_2_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, log_reg_2_pred)
ax1.plot(fpr, tpr, label="LogReg+Pipe", color='g')
ax2.plot(recall, precision, label="LogReg+Pipe", color='g')
print("LogReg+Pipe: AUC_PR = %.3f" % auc(recall, precision))
print("LogReg+Pipe: AUC_ROC = %.3f" % auc(fpr, tpr))


fpr, tpr, roc_thresholds = roc_curve(y_valid, catb_pred)
precision, recall, pr_thresholds = precision_recall_curve(y_valid, catb_pred)
ax1.plot(fpr, tpr, label="CatBoost", color='purple')
ax2.plot(recall, precision, label="CatBoost", color='purple')
print("CatBoost: AUC_PR = %.3f" % auc(recall, precision))
print("CatBoost: AUC_ROC = %.3f" % auc(fpr, tpr))
ax1.legend(loc="lower right")
ax2.legend(loc="lower right");
# Out:
# LogReg: AUC_PR = 0.086
# LogReg: AUC_ROC = 0.567
# LogReg+Pipe: AUC_PR = 0.374
# LogReg+Pipe: AUC_ROC = 0.872
# CatBoost: AUC_PR = 0.703
# CatBoost: AUC_ROC = 0.950

# %%
f.savefig('my_fig', quality = 95, dpi = 200)

# %% [markdown]
# ## Получение результата

# %% [markdown]
# ### Обучаем модель с наилучшими параметрами

# %%
result_model = catboost.CatBoostClassifier(n_estimators=200, max_depth=4, l2_leaf_reg =15, cat_features=['id', 'vas_id'],
                                      silent=True, random_state=21)

# %%
result_model.fit(X, y)

# %%
result_proba = result_model.predict_proba(X_test)

# %%
result = result_model.predict(X_test)

# %%
result.sum()
# Out:
# 1997.0

# %%
result_proba
# Out:
# array([[9.99242287e-01, 7.57712793e-04],
#        [8.35568898e-01, 1.64431102e-01],
#        [9.99235032e-01, 7.64968116e-04],
#        ...,
#        [9.99242287e-01, 7.57712793e-04],
#        [9.99241989e-01, 7.58010752e-04],
#        [9.99242287e-01, 7.57712793e-04]])

# %%
result_proba[:, 1]
# Out:
# array([0.00075771, 0.1644311 , 0.00076497, ..., 0.00075771, 0.00075801,
#        0.00075771])

# %%
result.shape
# Out:
# (71231,)

# %% [markdown]
# ### Формируем датафрейм с результатом для сохранения

# %%
answers_test = X_test[['id', 'vas_id', 'buy_time_x']]

# %%
answers_test
# Out:
#             id  vas_id  buy_time_x
# 0      3130519       2  1548018000
# 1      2000860       4  1548018000
# 2      1099444       2  1546808400
# 3      1343255       5  1547413200
# 4      1277040       2  1546808400
# ...        ...     ...         ...
# 71226  2502453       5  1548018000
# 71227  1693213       2  1548018000
# 71228  1891350       2  1548018000
# 71229  2437172       2  1548018000
# 71230   988236       2  1548018000
#
# [71231 rows x 3 columns]

# %%
target = pd.DataFrame(result_proba[:, 1], columns = ['target'])

# %%
target
# Out:
#          target
# 0      0.000758
# 1      0.164431
# 2      0.000765
# 3      0.000769
# 4      0.000759
# ...         ...
# 71226  0.000769
# 71227  0.000760
# 71228  0.000758
# 71229  0.000758
# 71230  0.000758
#
# [71231 rows x 1 columns]

# %%
answers_test = pd.concat([answers_test, target], axis=1)

# %%
answers_test.rename(columns={'buy_time_x': 'buy_time'}, inplace=True)

# %%
answers_test['vas_id'] = answers_test['vas_id'].astype('float')

# %%
answers_test
# Out:
#             id  vas_id    buy_time    target
# 0      3130519     2.0  1548018000  0.000758
# 1      2000860     4.0  1548018000  0.164431
# 2      1099444     2.0  1546808400  0.000765
# 3      1343255     5.0  1547413200  0.000769
# 4      1277040     2.0  1546808400  0.000759
# ...        ...     ...         ...       ...
# 71226  2502453     5.0  1548018000  0.000769
# 71227  1693213     2.0  1548018000  0.000760
# 71228  1891350     2.0  1548018000  0.000758
# 71229  2437172     2.0  1548018000  0.000758
# 71230   988236     2.0  1548018000  0.000758
#
# [71231 rows x 4 columns]

# %%
answers_test.to_csv('answers_test.csv')

# %% [markdown]
# ### Сохраняем итоговую модель (с проверкой)

# %%
result_model.save_model('result_model')

# %%
from_file = catboost.CatBoostClassifier()

# %%
from_file.load_model('result_model')

# %%
from_file.predict(X_test).sum()
# Out:
# 1997.0
