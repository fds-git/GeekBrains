# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import shapiro
from scipy.stats import probplot
from scipy.stats import ttest_ind, mannwhitneyu
from scipy.stats import chi2_contingency
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb, lightgbm as lgbm, catboost as catb
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import SelectPercentile, SelectFromModel, RFE

# %%
MODEL_1_FILE_PATH = '../model1.pkl'
MODEL_2_FILE_PATH = '../model2.pkl'
MODEL_3_FILE_PATH = '../model3.pkl'

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer

# %%
def show_feature_importances(feature_names, feature_importances, get_top=None):
    feature_importances = pd.DataFrame({'feature': feature_names, 'importance': feature_importances})
    feature_importances = feature_importances.sort_values('importance', ascending=False)
       
    plt.figure(figsize = (20, len(feature_importances) * 0.355))
    
    sns.barplot(feature_importances['importance'], feature_importances['feature'])
    
    plt.xlabel('Importance')
    plt.title('Importance of features')
    plt.show()
    
    if get_top is not None:
        return feature_importances['feature'][:get_top].tolist()

# %%
def balance_df_by_target(df, target_name):

    target_counts = df[target_name].value_counts()

    major_class_name = target_counts.argmax()
    minor_class_name = target_counts.argmin()

    disbalance_coeff = int(target_counts[major_class_name] / target_counts[minor_class_name]) - 1

    for i in range(disbalance_coeff):
        sample = df[df[target_name] == minor_class_name].sample(target_counts[minor_class_name])
        df = df.append(sample, ignore_index=True)

    return df.sample(frac=1)

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
TRAIN_DATASET_PATH = '../course_project_train.csv'
TEST_DATASET_PATH = '../course_project_test.csv'

# %%
TARGET_NAME = 'Credit Default'

# %%
df_train = pd.read_csv(TRAIN_DATASET_PATH)
df_train
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0          Own Home       482087.0                  NaN        0.0
# 1          Own Home      1025487.0            10+ years        0.0
# 2     Home Mortgage       751412.0              8 years        0.0
# 3          Own Home       805068.0              6 years        0.0
# 4              Rent       776264.0              8 years        0.0
# 5              Rent            NaN              7 years        0.0
# 6     Home Mortgage      1511108.0            10+ years        0.0
# 7              Rent      1040060.0            10+ years        0.0
# 8     Home Mortgage            NaN              5 years        0.0
# 9     Home Mortgage            NaN               1 year        0.0
# 10    Home Mortgage            NaN             < 1 year        0.0
# 11    Home Mortgage      1828560.0              4 years        0.0
# 12    Home Mortgage       933432.0            10+ years        0.0
# 13             Rent      2066364.0            10+ years        0.0
# 14         Own Home      2258796.0              7 years        0.0
# 15             Rent       848464.0            10+ years        0.0
# 16             Rent            NaN              7 years        0.0
# 17    Home Mortgage      3361898.0              3 years        0.0
# 18    Home Mortgage      1401744.0              2 years        0.0
# 19             Rent      1020072.0              2 years        0.0
# 20    Home Mortgage      1651993.0            10+ years        0.0
# 21    Home Mortgage      1047394.0              6 years        0.0
# 22             Rent       463790.0                  NaN        0.0
# 23         Own Home            NaN            10+ years        0.0
# 24         Own Home            NaN                  NaN        0.0
# 25             Rent      1353142.0            10+ years        0.0
# 26    Home Mortgage       951425.0              2 years        0.0
# 27             Rent      1004055.0              8 years        0.0
# 28    Home Mortgage       711094.0            10+ years        0.0
# 29             Rent            NaN            10+ years        0.0
# ...             ...            ...                  ...        ...
# 7470           Rent            NaN            10+ years        0.0
# 7471  Home Mortgage      1534839.0              4 years        0.0
# 7472  Home Mortgage      1043537.0              5 years        0.0
# 7473       Own Home      1644070.0            10+ years        0.0
# 7474       Own Home       743432.0              5 years        0.0
# 7475           Rent       848426.0            10+ years        0.0
# 7476  Home Mortgage      3358782.0            10+ years        0.0
# 7477           Rent      1995000.0              3 years        0.0
# 7478  Home Mortgage      3888160.0              6 years        0.0
# 7479       Own Home      1721932.0            10+ years        0.0
# 7480  Home Mortgage      1157974.0               1 year        0.0
# 7481  Home Mortgage      2127202.0            10+ years        0.0
# 7482  Home Mortgage            NaN            10+ years        0.0
# 7483           Rent       567435.0              8 years        0.0
# 7484  Home Mortgage      1258712.0              8 years        0.0
# 7485           Rent      2687664.0             < 1 year        0.0
# 7486           Rent      5327372.0               1 year        0.0
# 7487  Home Mortgage      1542952.0            10+ years        0.0
# 7488           Rent       465405.0              5 years        0.0
# 7489  Home Mortgage      1394942.0            10+ years        0.0
# 7490       Own Home      1368000.0            10+ years        0.0
# 7491  Home Mortgage      2833185.0              6 years        0.0
# 7492  Home Mortgage            NaN            10+ years        0.0
# 7493           Rent      1257610.0              8 years        0.0
# 7494       Own Home            NaN             < 1 year        0.0
# 7495           Rent       402192.0             < 1 year        0.0
# 7496  Home Mortgage      1533984.0               1 year        0.0
# 7497           Rent      1878910.0              6 years        0.0
# 7498  Home Mortgage            NaN                  NaN        0.0
# 7499           Rent            NaN              4 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 1                        15.0                     15.3            1181730.0
# 2                        11.0                     35.0            1182434.0
# 3                         8.0                     22.5             147400.0
# 4                        13.0                     13.6             385836.0
# 5                        12.0                     14.6             366784.0
# 6                         9.0                     20.3             388124.0
# 7                        13.0                     12.0             330374.0
# 8                        17.0                     15.7                  0.0
# 9                        10.0                     24.6             511302.0
# 10                        7.0                     11.5             256322.0
# 11                       12.0                     17.6             839080.0
# 12                        8.0                     14.0             443608.0
# 13                       11.0                     17.7            1654026.0
# 14                       11.0                     17.7            1602546.0
# 15                        9.0                     18.4             296186.0
# 16                        6.0                     17.8             899492.0
# 17                       14.0                     28.5            1042096.0
# 18                        9.0                     29.0             387222.0
# 19                        6.0                     12.5             199078.0
# 20                       11.0                     26.5             663894.0
# 21                        7.0                     34.4             401104.0
# 22                        6.0                     28.3             288442.0
# 23                       17.0                     14.8             700040.0
# 24                       12.0                     25.0            1216336.0
# 25                        3.0                     29.8            1231912.0
# 26                       20.0                     15.8             748880.0
# 27                        7.0                     14.5             328394.0
# 28                       12.0                     19.5             533808.0
# 29                        9.0                     18.6             186494.0
# ...                       ...                      ...                  ...
# 7470                     11.0                     22.6             431310.0
# 7471                     12.0                     19.0             427768.0
# 7472                      9.0                     14.7             726902.0
# 7473                     15.0                     33.5            4262654.0
# 7474                     11.0                     18.9             763642.0
# 7475                      8.0                     20.1             526306.0
# 7476                     12.0                     13.4             538340.0
# 7477                     16.0                     21.0             816618.0
# 7478                     30.0                     16.3            1435456.0
# 7479                      9.0                     28.0             912142.0
# 7480                     11.0                     27.9            1345652.0
# 7481                      7.0                     21.5             369116.0
# 7482                     14.0                     30.5             645062.0
# 7483                     11.0                     17.1             365750.0
# 7484                      6.0                      9.5             364210.0
# 7485                     14.0                     16.7             429154.0
# 7486                      7.0                     12.1             605638.0
# 7487                      7.0                     12.5             232364.0
# 7488                      5.0                      7.7              51744.0
# 7489                     15.0                     27.2            1441396.0
# 7490                     20.0                     26.7             897842.0
# 7491                     18.0                     21.3             280170.0
# 7492                     10.0                     13.3             423984.0
# 7493                     14.0                     16.5             821480.0
# 7494                      7.0                      8.2             301554.0
# 7495                      3.0                      8.5             107866.0
# 7496                     10.0                     26.5             686312.0
# 7497                     12.0                     32.1            1778920.0
# 7498                     21.0                     26.5            1141250.0
# 7499                      8.0                      9.4             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                           NaN           1.0
# 1                           0.0                           NaN           0.0
# 2                           0.0                           NaN           0.0
# 3                           1.0                           NaN           1.0
# 4                           1.0                           NaN           0.0
# 5                           0.0                           NaN           0.0
# 6                           0.0                          73.0           0.0
# 7                           0.0                          18.0           0.0
# 8                           1.0                           NaN           1.0
# 9                           0.0                           6.0           0.0
# 10                          0.0                           NaN           0.0
# 11                          0.0                           NaN           0.0
# 12                          0.0                           NaN           0.0
# 13                          0.0                           NaN           0.0
# 14                          0.0                           NaN           0.0
# 15                          0.0                           NaN           0.0
# 16                          0.0                           NaN           0.0
# 17                          0.0                           NaN           0.0
# 18                          0.0                          40.0           0.0
# 19                          0.0                           NaN           0.0
# 20                          0.0                          44.0           0.0
# 21                          0.0                          45.0           0.0
# 22                          0.0                           NaN           0.0
# 23                          0.0                          17.0           0.0
# 24                          0.0                          61.0           0.0
# 25                          0.0                           NaN           0.0
# 26                          0.0                           NaN           0.0
# 27                          0.0                           NaN           0.0
# 28                          0.0                           NaN           0.0
# 29                          0.0                           6.0           0.0
# ...                         ...                           ...           ...
# 7470                        0.0                          19.0           0.0
# 7471                        0.0                          34.0           0.0
# 7472                        0.0                           NaN           0.0
# 7473                        0.0                           NaN           0.0
# 7474                        0.0                          45.0           0.0
# 7475                        0.0                          12.0           0.0
# 7476                        0.0                           NaN           0.0
# 7477                        0.0                          49.0           0.0
# 7478                        0.0                          21.0           0.0
# 7479                        0.0                           NaN           0.0
# 7480                        0.0                          40.0           0.0
# 7481                        0.0                          27.0           0.0
# 7482                        0.0                          45.0           0.0
# 7483                        0.0                           8.0           0.0
# 7484                        0.0                           NaN           0.0
# 7485                        0.0                          77.0           0.0
# 7486                        0.0                           NaN           0.0
# 7487                        0.0                          59.0           0.0
# 7488                        0.0                          33.0           0.0
# 7489                        0.0                          35.0           0.0
# 7490                        0.0                          69.0           0.0
# 7491                        0.0                           6.0           0.0
# 7492                        0.0                           NaN           0.0
# 7493                        0.0                          58.0           0.0
# 7494                        0.0                           NaN           0.0
# 7495                        0.0                           NaN           0.0
# 7496                        0.0                          43.0           0.0
# 7497                        0.0                           NaN           0.0
# 7498                        0.0                           NaN           0.0
# 7499                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 0     debt consolidation  Short Term           99999999.0
# 1     debt consolidation   Long Term             264968.0
# 2     debt consolidation  Short Term           99999999.0
# 3     debt consolidation  Short Term             121396.0
# 4     debt consolidation  Short Term             125840.0
# 5                  other   Long Term             337304.0
# 6      home improvements  Short Term           99999999.0
# 7                  other  Short Term             250888.0
# 8      home improvements  Short Term             129734.0
# 9     debt consolidation   Long Term             572880.0
# 10    debt consolidation  Short Term             220858.0
# 11    debt consolidation  Short Term             441100.0
# 12    debt consolidation  Short Term             337766.0
# 13    debt consolidation   Long Term             549780.0
# 14                 other  Short Term             185262.0
# 15    debt consolidation  Short Term             145134.0
# 16    debt consolidation   Long Term             313038.0
# 17    debt consolidation   Long Term             498872.0
# 18    debt consolidation   Long Term             553586.0
# 19    debt consolidation  Short Term             309672.0
# 20    debt consolidation   Long Term             585090.0
# 21    debt consolidation  Short Term             324852.0
# 22    debt consolidation  Short Term           99999999.0
# 23    debt consolidation  Short Term             174878.0
# 24    debt consolidation  Short Term             467676.0
# 25                 other  Short Term             108042.0
# 26                 other  Short Term              66110.0
# 27    debt consolidation  Short Term           99999999.0
# 28    debt consolidation  Short Term             155782.0
# 29    debt consolidation  Short Term             357918.0
# ...                  ...         ...                  ...
# 7470  debt consolidation  Short Term              66352.0
# 7471  debt consolidation   Long Term             526570.0
# 7472  debt consolidation   Long Term             539902.0
# 7473  debt consolidation  Short Term              87516.0
# 7474  debt consolidation   Long Term             376618.0
# 7475  debt consolidation  Short Term           99999999.0
# 7476  debt consolidation  Short Term             324104.0
# 7477           buy a car  Short Term             528000.0
# 7478  debt consolidation  Short Term             787864.0
# 7479  debt consolidation  Short Term             105490.0
# 7480  debt consolidation  Short Term             432520.0
# 7481  debt consolidation  Short Term             559790.0
# 7482  debt consolidation  Short Term             188430.0
# 7483  debt consolidation   Long Term             328526.0
# 7484  debt consolidation  Short Term             161436.0
# 7485  debt consolidation  Short Term             466796.0
# 7486  debt consolidation  Short Term             111760.0
# 7487  debt consolidation   Long Term             267982.0
# 7488   home improvements  Short Term             129338.0
# 7489  debt consolidation  Short Term             753764.0
# 7490  debt consolidation  Short Term             683650.0
# 7491  debt consolidation  Short Term             437404.0
# 7492  debt consolidation  Short Term             332948.0
# 7493  debt consolidation   Long Term             448052.0
# 7494  debt consolidation  Short Term             290400.0
# 7495               other  Short Term             129360.0
# 7496  debt consolidation   Long Term             444048.0
# 7497           buy a car  Short Term           99999999.0
# 7498  debt consolidation  Short Term             615274.0
# 7499  debt consolidation  Short Term              26928.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                    47386.0        7914.0         749.0               0
# 1                   394972.0       18373.0         737.0               1
# 2                   308389.0       13651.0         742.0               0
# 3                    95855.0       11338.0         694.0               0
# 4                    93309.0        7180.0         719.0               0
# 5                   165680.0       18692.0           NaN               1
# 6                    51623.0        2317.0         745.0               0
# 7                    89015.0       19761.0         705.0               1
# 8                       19.0          17.0           NaN               0
# 9                   205333.0       17613.0           NaN               1
# 10                  187492.0       14592.0           NaN               0
# 11                  402914.0       15528.0         737.0               0
# 12                  315305.0       19446.0         706.0               0
# 13                 1037077.0       21869.0         728.0               1
# 14                 1374327.0       58352.0         748.0               0
# 15                   41439.0       12939.0         727.0               0
# 16                  538346.0       18844.0           NaN               1
# 17                  689396.0       52249.0         644.0               1
# 18                  201989.0       13434.0         695.0               1
# 19                  120517.0       14451.0         712.0               1
# 20                  252852.0        8742.0         697.0               0
# 21                  183597.0        7786.0         719.0               1
# 22                  157700.0        5063.0         738.0               0
# 23                  168074.0       17132.0           NaN               1
# 24                  818311.0       37530.0           NaN               0
# 25                 1036279.0       22225.0         720.0               0
# 26                  285874.0       17046.0         742.0               0
# 27                  195966.0        6041.0         734.0               0
# 28                  262314.0       13807.0         740.0               0
# 29                   72808.0       22352.0           NaN               1
# ...                      ...           ...           ...             ...
# 7470                248824.0       35285.0           NaN               0
# 7471                338409.0       30313.0         718.0               1
# 7472                315780.0       14262.0         726.0               1
# 7473               2256687.0       30963.0         737.0               0
# 7474                489364.0       15550.0         720.0               0
# 7475                 83638.0       16473.0         742.0               0
# 7476                292429.0       22084.0         721.0               0
# 7477                 29621.0        9559.0         750.0               1
# 7478                402914.0       93640.0         703.0               0
# 7479                723957.0       37022.0         739.0               0
# 7480                176643.0        8183.0         747.0               0
# 7481                303164.0       16380.0         739.0               0
# 7482                518662.0       23506.0           NaN               0
# 7483                181944.0        6431.0         658.0               1
# 7484                 93100.0        4689.0         741.0               0
# 7485                278711.0       44122.0         736.0               1
# 7486                292904.0        8080.0         750.0               0
# 7487                198873.0       15430.0         695.0               1
# 7488                  8721.0       13535.0         728.0               0
# 7489                496698.0       16972.0         742.0               1
# 7490                517199.0       29868.0         688.0               1
# 7491                108889.0       61150.0         704.0               0
# 7492                161481.0       20966.0           NaN               0
# 7493                167428.0       27562.0         676.0               1
# 7494                210938.0        5070.0           NaN               0
# 7495                 73492.0        1900.0         697.0               0
# 7496                456399.0       12783.0        7410.0               1
# 7497                477812.0       12479.0         748.0               0
# 7498                476064.0       37118.0           NaN               0
# 7499                288192.0        9061.0           NaN               0
#
# [7500 rows x 17 columns]

# %%
df_test = pd.read_csv(TEST_DATASET_PATH)
df_test
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0              Rent            NaN              4 years        0.0
# 1              Rent       231838.0               1 year        0.0
# 2     Home Mortgage      1152540.0              3 years        0.0
# 3     Home Mortgage      1220313.0            10+ years        0.0
# 4     Home Mortgage      2340952.0              6 years        0.0
# 5     Home Mortgage       922583.0              5 years        0.0
# 6     Home Mortgage      1233309.0              3 years        0.0
# 7              Rent      1215867.0              3 years        0.0
# 8              Rent            NaN              5 years        0.0
# 9     Home Mortgage      2140445.0            10+ years        1.0
# 10         Own Home       941355.0             < 1 year        0.0
# 11    Home Mortgage      1571737.0            10+ years        0.0
# 12    Home Mortgage      1054614.0              2 years        0.0
# 13             Rent      1232530.0              3 years        0.0
# 14    Home Mortgage      1473887.0             < 1 year        0.0
# 15             Rent      1118302.0            10+ years        0.0
# 16             Rent            NaN               1 year        0.0
# 17    Home Mortgage      1246495.0              9 years        0.0
# 18    Home Mortgage      2207743.0            10+ years        0.0
# 19             Rent      2295276.0              8 years        0.0
# 20    Home Mortgage            NaN              5 years        0.0
# 21    Home Mortgage       715350.0              8 years        0.0
# 22         Own Home       960735.0              8 years        0.0
# 23    Home Mortgage      2475928.0              2 years        0.0
# 24    Home Mortgage       950190.0               1 year        0.0
# 25    Home Mortgage       736516.0              6 years        0.0
# 26    Home Mortgage       835506.0             < 1 year        0.0
# 27    Home Mortgage            NaN              6 years        0.0
# 28         Own Home       651833.0              8 years        0.0
# 29             Rent      1025145.0              8 years        0.0
# ...             ...            ...                  ...        ...
# 2470  Home Mortgage      1116972.0              8 years        0.0
# 2471           Rent       640509.0             < 1 year        0.0
# 2472  Home Mortgage      1951110.0             < 1 year        0.0
# 2473           Rent      1139316.0              2 years        0.0
# 2474           Rent       471295.0             < 1 year        0.0
# 2475           Rent            NaN              6 years        0.0
# 2476  Home Mortgage      1331064.0              5 years        0.0
# 2477           Rent       667603.0              2 years        0.0
# 2478  Home Mortgage      1302070.0            10+ years        0.0
# 2479  Home Mortgage            NaN              3 years        0.0
# 2480  Home Mortgage       485507.0             < 1 year        0.0
# 2481  Home Mortgage       307458.0              6 years        0.0
# 2482           Rent      1188127.0              9 years        0.0
# 2483  Home Mortgage       933660.0            10+ years        0.0
# 2484  Home Mortgage       583737.0              4 years        0.0
# 2485  Home Mortgage      2162903.0            10+ years        0.0
# 2486  Home Mortgage      1323787.0            10+ years        0.0
# 2487  Home Mortgage            NaN            10+ years        0.0
# 2488  Home Mortgage      1181135.0              7 years        0.0
# 2489       Own Home       950589.0              6 years        0.0
# 2490  Home Mortgage      1494464.0            10+ years        0.0
# 2491           Rent       916199.0              2 years        0.0
# 2492  Home Mortgage       750500.0              3 years        0.0
# 2493           Rent      2038282.0            10+ years        0.0
# 2494  Home Mortgage       907839.0               1 year        0.0
# 2495  Home Mortgage      1020053.0            10+ years        0.0
# 2496  Home Mortgage            NaN              2 years        0.0
# 2497  Home Mortgage      1171806.0              2 years        0.0
# 2498           Rent       723520.0            10+ years        0.0
# 2499           Rent      1694439.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                         9.0                     12.5             220968.0
# 1                         6.0                     32.7              55946.0
# 2                        10.0                     13.7             204600.0
# 3                        16.0                     17.0             456302.0
# 4                        11.0                     23.6            1207272.0
# 5                        26.0                     17.5             713174.0
# 6                         7.0                     22.0             376420.0
# 7                        13.0                     12.2             195888.0
# 8                         8.0                      9.1             370524.0
# 9                        15.0                     16.7             867680.0
# 10                       10.0                      5.7             573650.0
# 11                       11.0                     22.2             485342.0
# 12                       11.0                     14.0             306328.0
# 13                       15.0                     14.7             441518.0
# 14                       13.0                     15.1             329912.0
# 15                       16.0                     27.1             676720.0
# 16                       21.0                     10.4             613404.0
# 17                       10.0                     22.9             357456.0
# 18                       11.0                     24.3            1815682.0
# 19                       16.0                     33.0             509014.0
# 20                       10.0                     24.5            4092528.0
# 21                       16.0                     11.4             477004.0
# 22                       17.0                     11.8             512380.0
# 23                        8.0                     23.9            1208988.0
# 24                       12.0                     23.0              94600.0
# 25                       10.0                     15.4             237842.0
# 26                       10.0                     15.2             312026.0
# 27                       10.0                      6.4             631202.0
# 28                        8.0                     10.4             174636.0
# 29                       11.0                     14.5             233134.0
# ...                       ...                      ...                  ...
# 2470                      8.0                     14.0             351560.0
# 2471                      6.0                     11.0             431552.0
# 2472                     13.0                     24.1             440506.0
# 2473                     11.0                     21.9             233200.0
# 2474                      3.0                      7.3              28424.0
# 2475                     13.0                     13.5             455378.0
# 2476                     14.0                     15.2             512622.0
# 2477                      5.0                     12.3             333366.0
# 2478                     11.0                     14.1             667326.0
# 2479                     18.0                     11.6             606628.0
# 2480                      8.0                     15.2             605176.0
# 2481                      8.0                      8.2             491678.0
# 2482                     11.0                     15.3             179696.0
# 2483                     11.0                     21.3             428296.0
# 2484                     10.0                      9.9             365750.0
# 2485                     13.0                     15.0             571934.0
# 2486                     10.0                     45.6             922372.0
# 2487                     24.0                     36.6            3341228.0
# 2488                     15.0                      9.6             396858.0
# 2489                      9.0                     21.3             611182.0
# 2490                      5.0                     15.7             553234.0
# 2491                     16.0                     12.4             316382.0
# 2492                      5.0                      6.3             162998.0
# 2493                     15.0                     12.6             847000.0
# 2494                     14.0                     11.1             438526.0
# 2495                     14.0                     29.1             559152.0
# 2496                     15.0                     17.0            1737780.0
# 2497                     48.0                     12.8            1706430.0
# 2498                     14.0                     28.8             945780.0
# 2499                     12.0                     18.4            1199748.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           0.0                          70.0           0.0
# 1                           0.0                           8.0           0.0
# 2                           0.0                           NaN           0.0
# 3                           0.0                          70.0           0.0
# 4                           0.0                           NaN           0.0
# 5                           0.0                          41.0           0.0
# 6                           0.0                          43.0           0.0
# 7                           0.0                          19.0           0.0
# 8                           0.0                           NaN           0.0
# 9                           1.0                           9.0           0.0
# 10                          0.0                           NaN           0.0
# 11                          0.0                           NaN           0.0
# 12                          0.0                          69.0           0.0
# 13                          0.0                           NaN           0.0
# 14                          0.0                          41.0           0.0
# 15                          0.0                           NaN           0.0
# 16                          0.0                           NaN           0.0
# 17                          0.0                          40.0           0.0
# 18                          0.0                           NaN           0.0
# 19                          0.0                          48.0           0.0
# 20                          0.0                          26.0           0.0
# 21                          0.0                           NaN           0.0
# 22                          0.0                          29.0           0.0
# 23                          0.0                           NaN           0.0
# 24                          0.0                          16.0           0.0
# 25                          0.0                          39.0           0.0
# 26                          0.0                           NaN           0.0
# 27                          0.0                           NaN           0.0
# 28                          0.0                           NaN           0.0
# 29                          0.0                           4.0           0.0
# ...                         ...                           ...           ...
# 2470                        0.0                           NaN           0.0
# 2471                        0.0                           NaN           0.0
# 2472                        1.0                           NaN           1.0
# 2473                        0.0                          50.0           0.0
# 2474                        0.0                           NaN           0.0
# 2475                        0.0                          81.0           0.0
# 2476                        0.0                          41.0           0.0
# 2477                        0.0                           NaN           0.0
# 2478                        0.0                           NaN           0.0
# 2479                        0.0                          23.0           0.0
# 2480                        0.0                          67.0           0.0
# 2481                        0.0                           NaN           0.0
# 2482                        0.0                          59.0           0.0
# 2483                        0.0                          14.0           0.0
# 2484                        0.0                           NaN           0.0
# 2485                        0.0                           NaN           0.0
# 2486                        0.0                           NaN           0.0
# 2487                        0.0                           NaN           0.0
# 2488                        0.0                           NaN           0.0
# 2489                        0.0                           NaN           0.0
# 2490                        0.0                           NaN           0.0
# 2491                        0.0                          73.0           0.0
# 2492                        0.0                           NaN           0.0
# 2493                        0.0                           NaN           0.0
# 2494                        0.0                           NaN           0.0
# 2495                        1.0                          68.0           1.0
# 2496                        0.0                          77.0           0.0
# 2497                        0.0                           NaN           0.0
# 2498                        0.0                           NaN           0.0
# 2499                        1.0                          72.0           0.0
#
#                    Purpose        Term  Current Loan Amount  \
# 0       debt consolidation  Short Term             162470.0
# 1     educational expenses  Short Term              78298.0
# 2       debt consolidation  Short Term             200178.0
# 3       debt consolidation  Short Term             217382.0
# 4       debt consolidation   Long Term             777634.0
# 5       debt consolidation  Short Term              94028.0
# 6        home improvements  Short Term             454388.0
# 7       debt consolidation  Short Term             407726.0
# 8           major purchase  Short Term             131956.0
# 9       debt consolidation  Short Term             391336.0
# 10      debt consolidation  Short Term             327008.0
# 11      debt consolidation   Long Term             346654.0
# 12      debt consolidation  Short Term             155408.0
# 13      debt consolidation  Short Term             210782.0
# 14                   other   Long Term             291918.0
# 15      debt consolidation  Short Term             372834.0
# 16      debt consolidation  Short Term             557480.0
# 17      debt consolidation  Short Term           99999999.0
# 18      debt consolidation  Short Term             462792.0
# 19      debt consolidation   Long Term             221474.0
# 20      debt consolidation   Long Term             344476.0
# 21                   other  Short Term             261580.0
# 22      debt consolidation  Short Term           99999999.0
# 23       home improvements  Short Term             264638.0
# 24      debt consolidation  Short Term             105622.0
# 25               buy a car  Short Term             249106.0
# 26      debt consolidation   Long Term             263846.0
# 27      debt consolidation  Short Term             444576.0
# 28      debt consolidation  Short Term             140162.0
# 29           medical bills  Short Term              86328.0
# ...                    ...         ...                  ...
# 2470    debt consolidation   Long Term             258676.0
# 2471    debt consolidation  Short Term             267058.0
# 2472    debt consolidation  Short Term             129096.0
# 2473    debt consolidation  Short Term             219868.0
# 2474    debt consolidation  Short Term             174636.0
# 2475    debt consolidation  Short Term             182182.0
# 2476         business loan  Short Term              66044.0
# 2477    debt consolidation  Short Term             220858.0
# 2478    debt consolidation  Short Term             516912.0
# 2479    debt consolidation  Short Term             260458.0
# 2480    debt consolidation  Short Term              94446.0
# 2481    debt consolidation  Short Term              77880.0
# 2482    debt consolidation  Short Term             144232.0
# 2483    debt consolidation  Short Term             329736.0
# 2484     home improvements  Short Term              96888.0
# 2485    debt consolidation   Long Term             474056.0
# 2486    debt consolidation  Short Term             450824.0
# 2487    debt consolidation  Short Term             455950.0
# 2488    debt consolidation  Short Term             316690.0
# 2489    debt consolidation  Short Term             258984.0
# 2490    debt consolidation  Short Term             179784.0
# 2491                 other  Short Term             442024.0
# 2492                 other  Short Term             173800.0
# 2493    debt consolidation  Short Term             432256.0
# 2494    debt consolidation   Long Term             368786.0
# 2495    debt consolidation  Short Term           99999999.0
# 2496    debt consolidation  Short Term             468512.0
# 2497    debt consolidation  Short Term             430496.0
# 2498    debt consolidation  Short Term             257774.0
# 2499    debt consolidation   Long Term             763004.0
#
#       Current Credit Balance  Monthly Debt  Credit Score
# 0                   105906.0        6813.0           NaN
# 1                    46037.0        2318.0         699.0
# 2                   146490.0       18729.0        7260.0
# 3                   213199.0       27559.0         739.0
# 4                   425391.0       42605.0         706.0
# 5                   135508.0       11148.0         679.0
# 6                   292904.0        8181.0         685.0
# 7                   120099.0        7599.0         701.0
# 8                   237747.0       10112.0           NaN
# 9                   294500.0       18372.0         745.0
# 10                  192223.0        3750.0         737.0
# 11                  320226.0       35626.0         696.0
# 12                  202388.0       14940.0        7030.0
# 13                  228399.0       29889.0         720.0
# 14                  243333.0       17195.0         700.0
# 15                  506103.0       23671.0         711.0
# 16                  486856.0       26230.0           NaN
# 17                  294823.0       21086.0         729.0
# 18                  710334.0       19870.0         749.0
# 19                  126160.0       15168.0         738.0
# 20                  463011.0       12732.0           NaN
# 21                  183730.0        6975.0         728.0
# 22                  164179.0       17133.0         733.0
# 23                  199424.0        6623.0         751.0
# 24                   62016.0       15599.0         724.0
# 25                  107426.0        7795.0         734.0
# 26                  189183.0       14760.0         711.0
# 27                  378328.0       19038.0           NaN
# 28                   98933.0       11733.0         739.0
# 29                   52953.0       23578.0         734.0
# ...                      ...           ...           ...
# 2470                239552.0       14521.0        6470.0
# 2471                319048.0        7953.0         725.0
# 2472                 92454.0       25852.0        7410.0
# 2473                106343.0       23451.0         746.0
# 2474                  2603.0        3091.0         743.0
# 2475                149055.0       11688.0           NaN
# 2476                241718.0        9606.0         744.0
# 2477                152589.0        7622.0        7480.0
# 2478                512943.0       25282.0         746.0
# 2479                371963.0       18859.0           NaN
# 2480                 24035.0       13432.0         709.0
# 2481                 95969.0        4817.0         692.0
# 2482                 90003.0       23367.0         728.0
# 2483                331797.0       17973.0         714.0
# 2484                 20216.0        1420.0         747.0
# 2485                271681.0       36229.0         707.0
# 2486                452466.0       16327.0         741.0
# 2487               1255235.0       44682.0           NaN
# 2488                287565.0       21654.0         739.0
# 2489                360525.0       11724.0         740.0
# 2490                177745.0        3437.0         751.0
# 2491                 88521.0        2313.0         738.0
# 2492                110238.0        5741.0         690.0
# 2493                 88521.0       27177.0         692.0
# 2494                 88255.0       18838.0         705.0
# 2495                162735.0       15046.0         745.0
# 2496               1439269.0       32996.0           NaN
# 2497                676438.0       36912.0         695.0
# 2498                391248.0       13506.0         744.0
# 2499                559531.0       23440.0        6820.0
#
# [2500 rows x 16 columns]

# %%
sns.boxplot(df_train['Current Loan Amount'])

# %%
df_train[TARGET_NAME].value_counts()
# Out:
# 0    5387
# 1    2113
# Name: Credit Default, dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
# Home Ownership                  7500 non-null object
# Annual Income                   5943 non-null float64
# Years in current job            7129 non-null object
# Tax Liens                       7500 non-null float64
# Number of Open Accounts         7500 non-null float64
# Years of Credit History         7500 non-null float64
# Maximum Open Credit             7500 non-null float64
# Number of Credit Problems       7500 non-null float64
# Months since last delinquent    3419 non-null float64
# Bankruptcies                    7486 non-null float64
# Purpose                         7500 non-null object
# Term                            7500 non-null object
# Current Loan Amount             7500 non-null float64
# Current Credit Balance          7500 non-null float64
# Monthly Debt                    7500 non-null float64
# Credit Score                    5943 non-null float64
# Credit Default                  7500 non-null int64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 996.2+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
# Home Ownership                  2500 non-null object
# Annual Income                   1987 non-null float64
# Years in current job            2414 non-null object
# Tax Liens                       2500 non-null float64
# Number of Open Accounts         2500 non-null float64
# Years of Credit History         2500 non-null float64
# Maximum Open Credit             2500 non-null float64
# Number of Credit Problems       2500 non-null float64
# Months since last delinquent    1142 non-null float64
# Bankruptcies                    2497 non-null float64
# Purpose                         2500 non-null object
# Term                            2500 non-null object
# Current Loan Amount             2500 non-null float64
# Current Credit Balance          2500 non-null float64
# Monthly Debt                    2500 non-null float64
# Credit Score                    1987 non-null float64
# dtypes: float64(12), object(4)
# memory usage: 312.6+ KB

# %% [markdown]
# ## Анализ целевой переменной

# %%
TARGET_NAME = 'Credit Default'

# %%
df_train['Credit Default'].value_counts()
# Out:
# 0    5387
# 1    2113
# Name: Credit Default, dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(x=TARGET_NAME, data=df_train)

plt.title('Target variable distribution')
plt.show()

# %% [markdown]
# ## Работа с категориальными переменными

# %% [markdown]
# ### Работа с Purpose

# %%
df_train['Purpose'].value_counts()
# Out:
# debt consolidation      5944
# other                    665
# home improvements        412
# business loan            129
# buy a car                 96
# medical bills             71
# major purchase            40
# take a trip               37
# buy house                 34
# small business            26
# wedding                   15
# moving                    11
# educational expenses      10
# vacation                   8
# renewable energy           2
# Name: Purpose, dtype: int64

# %%
term_with_target = df_train[['Purpose', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()

# %%
table = term_with_target.pivot_table(values='index', index='Purpose', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default             0       1
# Purpose
# business loan           74.0    55.0
# buy a car               72.0    24.0
# buy house               25.0     9.0
# debt consolidation    4290.0  1654.0
# educational expenses     9.0     1.0
# home improvements      304.0   108.0
# major purchase          31.0     9.0
# medical bills           49.0    22.0
# moving                   9.0     2.0
# other                  468.0   197.0
# renewable energy         NaN     2.0
# small business          12.0    14.0
# take a trip             27.0    10.0
# vacation                 6.0     2.0
# wedding                 11.0     4.0

# %% [markdown]
# разделим на 3 класса: в одном больше погасили кредит, во втором - нет

# %% [markdown]
# class1: business loan + renewable energy + small business

# %% [markdown]
# class2: debt consolidation + other + medical bills

# %% [markdown]
# class3: buy a car + buy house + educational expenses + home improvements + major purchase + take a trip + vacation + wedding

# %%
plt.figure(figsize=(20, 8))
sns.countplot(x="Purpose", hue='Credit Default', data=df_train)
plt.title('Purpose grouped by target variable')
plt.legend(title='Target', loc='upper right')

# %%
df_train.loc[df_train['Purpose'] == 'business loan', ['Purpose']] = 'Class1'
df_train.loc[df_train['Purpose'] == 'renewable energy', ['Purpose']] = 'Class1'
df_train.loc[df_train['Purpose'] == 'small business', ['Purpose']] = 'Class1'

# %%
df_train.loc[df_train['Purpose'] == 'debt consolidation', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'other', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'medical bills', ['Purpose']] = 'Class2'

df_train.loc[df_train['Purpose'] == 'buy a car', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'buy house', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'educational expenses', ['Purpose']] = 'Class2'

df_train.loc[df_train['Purpose'] == 'home improvements', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'major purchase', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'take a trip', ['Purpose']] = 'Class2'

df_train.loc[df_train['Purpose'] == 'vacation', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'wedding', ['Purpose']] = 'Class2'
df_train.loc[df_train['Purpose'] == 'moving', ['Purpose']] = 'Class2'

# %%
df_test.loc[df_test['Purpose'] == 'business loan', ['Purpose']] = 'Class1'
df_test.loc[df_test['Purpose'] == 'renewable energy', ['Purpose']] = 'Class1'
df_test.loc[df_test['Purpose'] == 'small business', ['Purpose']] = 'Class1'

# %%
df_test.loc[df_test['Purpose'] == 'debt consolidation', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'other', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'medical bills', ['Purpose']] = 'Class2'

df_test.loc[df_test['Purpose'] == 'buy a car', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'buy house', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'educational expenses', ['Purpose']] = 'Class2'

df_test.loc[df_test['Purpose'] == 'home improvements', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'major purchase', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'take a trip', ['Purpose']] = 'Class2'

df_test.loc[df_test['Purpose'] == 'vacation', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'wedding', ['Purpose']] = 'Class2'
df_test.loc[df_test['Purpose'] == 'moving', ['Purpose']] = 'Class2'

# %%
term_with_target = df_train[['Purpose', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()

# %%
table = term_with_target.pivot_table(values='index', index='Purpose', columns='Credit Default', aggfunc='count')

# %%
table
# Out:
# Credit Default     0     1
# Purpose
# Class1            86    71
# Class2          5301  2042

# %%
plt.figure(figsize=(20, 8))
sns.countplot(x="Purpose", hue='Credit Default', data=df_train)
plt.title('Purpose grouped by target variable')
plt.legend(title='Target', loc='upper right')

# %% [markdown]
# ### Работа с Tax Liens

# %%
df_train['Tax Liens'].value_counts()
# Out:
# 0.0    7366
# 1.0      83
# 2.0      30
# 3.0      10
# 4.0       6
# 5.0       2
# 6.0       2
# 7.0       1
# Name: Tax Liens, dtype: int64

# %%
term_with_target = df_train[['Tax Liens', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()
table = term_with_target.pivot_table(values='index', index='Tax Liens', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default       0       1
# Tax Liens
# 0.0             5301.0  2065.0
# 1.0               59.0    24.0
# 2.0               15.0    15.0
# 3.0                5.0     5.0
# 4.0                3.0     3.0
# 5.0                1.0     1.0
# 6.0                2.0     NaN
# 7.0                1.0     NaN

# %%
a = df_train.loc[df_train['Credit Default'] == 0, 'Tax Liens'].reset_index()
b = df_train.loc[df_train['Credit Default'] == 1, 'Tax Liens'].reset_index()

# %%
sns.kdeplot(a['Tax Liens'], shade=True)

# %%
sns.kdeplot(b['Tax Liens'], shade=True)

# %%
df_train.loc[df_train['Tax Liens'] <= 1.1, ['Tax Liens']] = 'Less_equ_1'
df_train.loc[df_train['Tax Liens'] != 'Less_equ_1', ['Tax Liens']] = 'More_equ_2'

# %%
df_test.loc[df_test['Tax Liens'] <= 1.1, ['Tax Liens']] = 'Less_equ_1'
df_test.loc[df_test['Tax Liens'] != 'Less_equ_1', ['Tax Liens']] = 'More_equ_2'

# %%
term_with_target = df_train[['Tax Liens', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()
table = term_with_target.pivot_table(values='index', index='Tax Liens', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default     0     1
# Tax Liens
# Less_equ_1      5360  2089
# More_equ_2        27    24

# %% [markdown]
# ### Работа с Number of Open Accounts

# %%
term_with_target = df_train[['Number of Open Accounts', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()
table = term_with_target.pivot_table(values='index', index='Number of Open Accounts', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default               0      1
# Number of Open Accounts
# 2.0                       19.0    9.0
# 3.0                       71.0   24.0
# 4.0                      156.0   56.0
# 5.0                      231.0   94.0
# 6.0                      374.0  130.0
# 7.0                      455.0  158.0
# 8.0                      480.0  158.0
# 9.0                      513.0  215.0
# 10.0                     480.0  197.0
# 11.0                     516.0  176.0
# 12.0                     397.0  165.0
# 13.0                     327.0  138.0
# 14.0                     290.0  130.0
# 15.0                     223.0   90.0
# 16.0                     181.0   84.0
# 17.0                     168.0   64.0
# 18.0                      98.0   45.0
# 19.0                      97.0   42.0
# 20.0                      56.0   37.0
# 21.0                      58.0   20.0
# 22.0                      35.0   14.0
# 23.0                      40.0   19.0
# 24.0                      39.0   11.0
# 25.0                      23.0    9.0
# 26.0                      11.0    1.0
# 27.0                       9.0    5.0
# 28.0                       8.0    6.0
# 29.0                       5.0    5.0
# 30.0                       9.0    2.0
# 31.0                       5.0    1.0
# 32.0                       5.0    1.0
# 33.0                       3.0    3.0
# 34.0                       1.0    1.0
# 35.0                       NaN    1.0
# 37.0                       2.0    NaN
# 38.0                       NaN    1.0
# 41.0                       1.0    NaN
# 42.0                       NaN    1.0
# 43.0                       1.0    NaN

# %%
a = df_train.loc[df_train['Credit Default'] == 0, 'Number of Open Accounts'].reset_index()

# %%
b = df_train.loc[df_train['Credit Default'] == 1, 'Number of Open Accounts'].reset_index()

# %%
sns.kdeplot(a['Number of Open Accounts'], shade=True)
sns.kdeplot(b['Number of Open Accounts'], shade=True)

# %% [markdown]
# Очень сложно разделить

# %% [markdown]
# ### Работа с Number of Credit Problems

# %%
df_train['Number of Credit Problems'].value_counts()
# Out:
# 0.0    6469
# 1.0     882
# 2.0      93
# 3.0      35
# 4.0       9
# 5.0       7
# 6.0       4
# 7.0       1
# Name: Number of Credit Problems, dtype: int64

# %%
term_with_target = df_train[['Number of Credit Problems', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()
table = term_with_target.pivot_table(values='index', index='Number of Credit Problems', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default                  0       1
# Number of Credit Problems
# 0.0                        4654.0  1815.0
# 1.0                         641.0   241.0
# 2.0                          60.0    33.0
# 3.0                          21.0    14.0
# 4.0                           3.0     6.0
# 5.0                           3.0     4.0
# 6.0                           4.0     NaN
# 7.0                           1.0     NaN

# %%
df_train.loc[df_train['Number of Credit Problems'] <= 3.5, ['Number of Credit Problems']] = 'Less_equ_3'
df_train.loc[df_train['Number of Credit Problems'] != 'Less_equ_3', ['Number of Credit Problems']] = 'More_equ_4'

# %%
df_test.loc[df_test['Number of Credit Problems'] <= 3.5, ['Number of Credit Problems']] = 'Less_equ_3'
df_test.loc[df_test['Number of Credit Problems'] != 'Less_equ_3', ['Number of Credit Problems']] = 'More_equ_4'

# %% [markdown]
# ### Работа с Bankruptcies

# %%
df_train['Bankruptcies'].value_counts()
# Out:
# 0.0    6660
# 1.0     786
# 2.0      31
# 3.0       7
# 4.0       2
# Name: Bankruptcies, dtype: int64

# %%
term_with_target = df_train[['Bankruptcies', 'Credit Default']]#.sample(1000)
term_with_target = term_with_target.reset_index()
table = term_with_target.pivot_table(values='index', index='Bankruptcies', columns='Credit Default', aggfunc='count')
table
# Out:
# Credit Default     0     1
# Bankruptcies
# 0.0             4782  1878
# 1.0              569   217
# 2.0               20    11
# 3.0                5     2
# 4.0                1     1

# %% [markdown]
# Если разделять , то во втором классе получится очень мало значений, поэтому нет смысла

# %% [markdown]
# ## Слияние df_train и df_test для одновременной обработки

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
# Home Ownership                  2500 non-null object
# Annual Income                   1987 non-null float64
# Years in current job            2414 non-null object
# Tax Liens                       2500 non-null object
# Number of Open Accounts         2500 non-null float64
# Years of Credit History         2500 non-null float64
# Maximum Open Credit             2500 non-null float64
# Number of Credit Problems       2500 non-null object
# Months since last delinquent    1142 non-null float64
# Bankruptcies                    2497 non-null float64
# Purpose                         2500 non-null object
# Term                            2500 non-null object
# Current Loan Amount             2500 non-null float64
# Current Credit Balance          2500 non-null float64
# Monthly Debt                    2500 non-null float64
# Credit Score                    1987 non-null float64
# dtypes: float64(10), object(6)
# memory usage: 312.6+ KB

# %%
y_df = df_train[TARGET_NAME]

# %%
df_train = df_train.drop(TARGET_NAME, axis=1)

# %%
df_train.shape
# Out:
# (7500, 16)

# %%
df_test.shape
# Out:
# (2500, 16)

# %%
df = pd.concat([df_train, df_test], axis=0).reset_index()

# %%
df
# Out:
#       index Home Ownership  Annual Income Years in current job   Tax Liens  \
# 0         0       Own Home       482087.0                  NaN  Less_equ_1
# 1         1       Own Home      1025487.0            10+ years  Less_equ_1
# 2         2  Home Mortgage       751412.0              8 years  Less_equ_1
# 3         3       Own Home       805068.0              6 years  Less_equ_1
# 4         4           Rent       776264.0              8 years  Less_equ_1
# 5         5           Rent            NaN              7 years  Less_equ_1
# 6         6  Home Mortgage      1511108.0            10+ years  Less_equ_1
# 7         7           Rent      1040060.0            10+ years  Less_equ_1
# 8         8  Home Mortgage            NaN              5 years  Less_equ_1
# 9         9  Home Mortgage            NaN               1 year  Less_equ_1
# 10       10  Home Mortgage            NaN             < 1 year  Less_equ_1
# 11       11  Home Mortgage      1828560.0              4 years  Less_equ_1
# 12       12  Home Mortgage       933432.0            10+ years  Less_equ_1
# 13       13           Rent      2066364.0            10+ years  Less_equ_1
# 14       14       Own Home      2258796.0              7 years  Less_equ_1
# 15       15           Rent       848464.0            10+ years  Less_equ_1
# 16       16           Rent            NaN              7 years  Less_equ_1
# 17       17  Home Mortgage      3361898.0              3 years  Less_equ_1
# 18       18  Home Mortgage      1401744.0              2 years  Less_equ_1
# 19       19           Rent      1020072.0              2 years  Less_equ_1
# 20       20  Home Mortgage      1651993.0            10+ years  Less_equ_1
# 21       21  Home Mortgage      1047394.0              6 years  Less_equ_1
# 22       22           Rent       463790.0                  NaN  Less_equ_1
# 23       23       Own Home            NaN            10+ years  Less_equ_1
# 24       24       Own Home            NaN                  NaN  Less_equ_1
# 25       25           Rent      1353142.0            10+ years  Less_equ_1
# 26       26  Home Mortgage       951425.0              2 years  Less_equ_1
# 27       27           Rent      1004055.0              8 years  Less_equ_1
# 28       28  Home Mortgage       711094.0            10+ years  Less_equ_1
# 29       29           Rent            NaN            10+ years  Less_equ_1
# ...     ...            ...            ...                  ...         ...
# 9970   2470  Home Mortgage      1116972.0              8 years  Less_equ_1
# 9971   2471           Rent       640509.0             < 1 year  Less_equ_1
# 9972   2472  Home Mortgage      1951110.0             < 1 year  Less_equ_1
# 9973   2473           Rent      1139316.0              2 years  Less_equ_1
# 9974   2474           Rent       471295.0             < 1 year  Less_equ_1
# 9975   2475           Rent            NaN              6 years  Less_equ_1
# 9976   2476  Home Mortgage      1331064.0              5 years  Less_equ_1
# 9977   2477           Rent       667603.0              2 years  Less_equ_1
# 9978   2478  Home Mortgage      1302070.0            10+ years  Less_equ_1
# 9979   2479  Home Mortgage            NaN              3 years  Less_equ_1
# 9980   2480  Home Mortgage       485507.0             < 1 year  Less_equ_1
# 9981   2481  Home Mortgage       307458.0              6 years  Less_equ_1
# 9982   2482           Rent      1188127.0              9 years  Less_equ_1
# 9983   2483  Home Mortgage       933660.0            10+ years  Less_equ_1
# 9984   2484  Home Mortgage       583737.0              4 years  Less_equ_1
# 9985   2485  Home Mortgage      2162903.0            10+ years  Less_equ_1
# 9986   2486  Home Mortgage      1323787.0            10+ years  Less_equ_1
# 9987   2487  Home Mortgage            NaN            10+ years  Less_equ_1
# 9988   2488  Home Mortgage      1181135.0              7 years  Less_equ_1
# 9989   2489       Own Home       950589.0              6 years  Less_equ_1
# 9990   2490  Home Mortgage      1494464.0            10+ years  Less_equ_1
# 9991   2491           Rent       916199.0              2 years  Less_equ_1
# 9992   2492  Home Mortgage       750500.0              3 years  Less_equ_1
# 9993   2493           Rent      2038282.0            10+ years  Less_equ_1
# 9994   2494  Home Mortgage       907839.0               1 year  Less_equ_1
# 9995   2495  Home Mortgage      1020053.0            10+ years  Less_equ_1
# 9996   2496  Home Mortgage            NaN              2 years  Less_equ_1
# 9997   2497  Home Mortgage      1171806.0              2 years  Less_equ_1
# 9998   2498           Rent       723520.0            10+ years  Less_equ_1
# 9999   2499           Rent      1694439.0            10+ years  Less_equ_1
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 1                        15.0                     15.3            1181730.0
# 2                        11.0                     35.0            1182434.0
# 3                         8.0                     22.5             147400.0
# 4                        13.0                     13.6             385836.0
# 5                        12.0                     14.6             366784.0
# 6                         9.0                     20.3             388124.0
# 7                        13.0                     12.0             330374.0
# 8                        17.0                     15.7                  0.0
# 9                        10.0                     24.6             511302.0
# 10                        7.0                     11.5             256322.0
# 11                       12.0                     17.6             839080.0
# 12                        8.0                     14.0             443608.0
# 13                       11.0                     17.7            1654026.0
# 14                       11.0                     17.7            1602546.0
# 15                        9.0                     18.4             296186.0
# 16                        6.0                     17.8             899492.0
# 17                       14.0                     28.5            1042096.0
# 18                        9.0                     29.0             387222.0
# 19                        6.0                     12.5             199078.0
# 20                       11.0                     26.5             663894.0
# 21                        7.0                     34.4             401104.0
# 22                        6.0                     28.3             288442.0
# 23                       17.0                     14.8             700040.0
# 24                       12.0                     25.0            1216336.0
# 25                        3.0                     29.8            1231912.0
# 26                       20.0                     15.8             748880.0
# 27                        7.0                     14.5             328394.0
# 28                       12.0                     19.5             533808.0
# 29                        9.0                     18.6             186494.0
# ...                       ...                      ...                  ...
# 9970                      8.0                     14.0             351560.0
# 9971                      6.0                     11.0             431552.0
# 9972                     13.0                     24.1             440506.0
# 9973                     11.0                     21.9             233200.0
# 9974                      3.0                      7.3              28424.0
# 9975                     13.0                     13.5             455378.0
# 9976                     14.0                     15.2             512622.0
# 9977                      5.0                     12.3             333366.0
# 9978                     11.0                     14.1             667326.0
# 9979                     18.0                     11.6             606628.0
# 9980                      8.0                     15.2             605176.0
# 9981                      8.0                      8.2             491678.0
# 9982                     11.0                     15.3             179696.0
# 9983                     11.0                     21.3             428296.0
# 9984                     10.0                      9.9             365750.0
# 9985                     13.0                     15.0             571934.0
# 9986                     10.0                     45.6             922372.0
# 9987                     24.0                     36.6            3341228.0
# 9988                     15.0                      9.6             396858.0
# 9989                      9.0                     21.3             611182.0
# 9990                      5.0                     15.7             553234.0
# 9991                     16.0                     12.4             316382.0
# 9992                      5.0                      6.3             162998.0
# 9993                     15.0                     12.6             847000.0
# 9994                     14.0                     11.1             438526.0
# 9995                     14.0                     29.1             559152.0
# 9996                     15.0                     17.0            1737780.0
# 9997                     48.0                     12.8            1706430.0
# 9998                     14.0                     28.8             945780.0
# 9999                     12.0                     18.4            1199748.0
#
#      Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                   Less_equ_3                           NaN           1.0
# 1                   Less_equ_3                           NaN           0.0
# 2                   Less_equ_3                           NaN           0.0
# 3                   Less_equ_3                           NaN           1.0
# 4                   Less_equ_3                           NaN           0.0
# 5                   Less_equ_3                           NaN           0.0
# 6                   Less_equ_3                          73.0           0.0
# 7                   Less_equ_3                          18.0           0.0
# 8                   Less_equ_3                           NaN           1.0
# 9                   Less_equ_3                           6.0           0.0
# 10                  Less_equ_3                           NaN           0.0
# 11                  Less_equ_3                           NaN           0.0
# 12                  Less_equ_3                           NaN           0.0
# 13                  Less_equ_3                           NaN           0.0
# 14                  Less_equ_3                           NaN           0.0
# 15                  Less_equ_3                           NaN           0.0
# 16                  Less_equ_3                           NaN           0.0
# 17                  Less_equ_3                           NaN           0.0
# 18                  Less_equ_3                          40.0           0.0
# 19                  Less_equ_3                           NaN           0.0
# 20                  Less_equ_3                          44.0           0.0
# 21                  Less_equ_3                          45.0           0.0
# 22                  Less_equ_3                           NaN           0.0
# 23                  Less_equ_3                          17.0           0.0
# 24                  Less_equ_3                          61.0           0.0
# 25                  Less_equ_3                           NaN           0.0
# 26                  Less_equ_3                           NaN           0.0
# 27                  Less_equ_3                           NaN           0.0
# 28                  Less_equ_3                           NaN           0.0
# 29                  Less_equ_3                           6.0           0.0
# ...                        ...                           ...           ...
# 9970                Less_equ_3                           NaN           0.0
# 9971                Less_equ_3                           NaN           0.0
# 9972                Less_equ_3                           NaN           1.0
# 9973                Less_equ_3                          50.0           0.0
# 9974                Less_equ_3                           NaN           0.0
# 9975                Less_equ_3                          81.0           0.0
# 9976                Less_equ_3                          41.0           0.0
# 9977                Less_equ_3                           NaN           0.0
# 9978                Less_equ_3                           NaN           0.0
# 9979                Less_equ_3                          23.0           0.0
# 9980                Less_equ_3                          67.0           0.0
# 9981                Less_equ_3                           NaN           0.0
# 9982                Less_equ_3                          59.0           0.0
# 9983                Less_equ_3                          14.0           0.0
# 9984                Less_equ_3                           NaN           0.0
# 9985                Less_equ_3                           NaN           0.0
# 9986                Less_equ_3                           NaN           0.0
# 9987                Less_equ_3                           NaN           0.0
# 9988                Less_equ_3                           NaN           0.0
# 9989                Less_equ_3                           NaN           0.0
# 9990                Less_equ_3                           NaN           0.0
# 9991                Less_equ_3                          73.0           0.0
# 9992                Less_equ_3                           NaN           0.0
# 9993                Less_equ_3                           NaN           0.0
# 9994                Less_equ_3                           NaN           0.0
# 9995                Less_equ_3                          68.0           1.0
# 9996                Less_equ_3                          77.0           0.0
# 9997                Less_equ_3                           NaN           0.0
# 9998                Less_equ_3                           NaN           0.0
# 9999                Less_equ_3                          72.0           0.0
#
#      Purpose        Term  Current Loan Amount  Current Credit Balance  \
# 0     Class2  Short Term           99999999.0                 47386.0
# 1     Class2   Long Term             264968.0                394972.0
# 2     Class2  Short Term           99999999.0                308389.0
# 3     Class2  Short Term             121396.0                 95855.0
# 4     Class2  Short Term             125840.0                 93309.0
# 5     Class2   Long Term             337304.0                165680.0
# 6     Class2  Short Term           99999999.0                 51623.0
# 7     Class2  Short Term             250888.0                 89015.0
# 8     Class2  Short Term             129734.0                    19.0
# 9     Class2   Long Term             572880.0                205333.0
# 10    Class2  Short Term             220858.0                187492.0
# 11    Class2  Short Term             441100.0                402914.0
# 12    Class2  Short Term             337766.0                315305.0
# 13    Class2   Long Term             549780.0               1037077.0
# 14    Class2  Short Term             185262.0               1374327.0
# 15    Class2  Short Term             145134.0                 41439.0
# 16    Class2   Long Term             313038.0                538346.0
# 17    Class2   Long Term             498872.0                689396.0
# 18    Class2   Long Term             553586.0                201989.0
# 19    Class2  Short Term             309672.0                120517.0
# 20    Class2   Long Term             585090.0                252852.0
# 21    Class2  Short Term             324852.0                183597.0
# 22    Class2  Short Term           99999999.0                157700.0
# 23    Class2  Short Term             174878.0                168074.0
# 24    Class2  Short Term             467676.0                818311.0
# 25    Class2  Short Term             108042.0               1036279.0
# 26    Class2  Short Term              66110.0                285874.0
# 27    Class2  Short Term           99999999.0                195966.0
# 28    Class2  Short Term             155782.0                262314.0
# 29    Class2  Short Term             357918.0                 72808.0
# ...      ...         ...                  ...                     ...
# 9970  Class2   Long Term             258676.0                239552.0
# 9971  Class2  Short Term             267058.0                319048.0
# 9972  Class2  Short Term             129096.0                 92454.0
# 9973  Class2  Short Term             219868.0                106343.0
# 9974  Class2  Short Term             174636.0                  2603.0
# 9975  Class2  Short Term             182182.0                149055.0
# 9976  Class1  Short Term              66044.0                241718.0
# 9977  Class2  Short Term             220858.0                152589.0
# 9978  Class2  Short Term             516912.0                512943.0
# 9979  Class2  Short Term             260458.0                371963.0
# 9980  Class2  Short Term              94446.0                 24035.0
# 9981  Class2  Short Term              77880.0                 95969.0
# 9982  Class2  Short Term             144232.0                 90003.0
# 9983  Class2  Short Term             329736.0                331797.0
# 9984  Class2  Short Term              96888.0                 20216.0
# 9985  Class2   Long Term             474056.0                271681.0
# 9986  Class2  Short Term             450824.0                452466.0
# 9987  Class2  Short Term             455950.0               1255235.0
# 9988  Class2  Short Term             316690.0                287565.0
# 9989  Class2  Short Term             258984.0                360525.0
# 9990  Class2  Short Term             179784.0                177745.0
# 9991  Class2  Short Term             442024.0                 88521.0
# 9992  Class2  Short Term             173800.0                110238.0
# 9993  Class2  Short Term             432256.0                 88521.0
# 9994  Class2   Long Term             368786.0                 88255.0
# 9995  Class2  Short Term           99999999.0                162735.0
# 9996  Class2  Short Term             468512.0               1439269.0
# 9997  Class2  Short Term             430496.0                676438.0
# 9998  Class2  Short Term             257774.0                391248.0
# 9999  Class2   Long Term             763004.0                559531.0
#
#       Monthly Debt  Credit Score
# 0           7914.0         749.0
# 1          18373.0         737.0
# 2          13651.0         742.0
# 3          11338.0         694.0
# 4           7180.0         719.0
# 5          18692.0           NaN
# 6           2317.0         745.0
# 7          19761.0         705.0
# 8             17.0           NaN
# 9          17613.0           NaN
# 10         14592.0           NaN
# 11         15528.0         737.0
# 12         19446.0         706.0
# 13         21869.0         728.0
# 14         58352.0         748.0
# 15         12939.0         727.0
# 16         18844.0           NaN
# 17         52249.0         644.0
# 18         13434.0         695.0
# 19         14451.0         712.0
# 20          8742.0         697.0
# 21          7786.0         719.0
# 22          5063.0         738.0
# 23         17132.0           NaN
# 24         37530.0           NaN
# 25         22225.0         720.0
# 26         17046.0         742.0
# 27          6041.0         734.0
# 28         13807.0         740.0
# 29         22352.0           NaN
# ...            ...           ...
# 9970       14521.0        6470.0
# 9971        7953.0         725.0
# 9972       25852.0        7410.0
# 9973       23451.0         746.0
# 9974        3091.0         743.0
# 9975       11688.0           NaN
# 9976        9606.0         744.0
# 9977        7622.0        7480.0
# 9978       25282.0         746.0
# 9979       18859.0           NaN
# 9980       13432.0         709.0
# 9981        4817.0         692.0
# 9982       23367.0         728.0
# 9983       17973.0         714.0
# 9984        1420.0         747.0
# 9985       36229.0         707.0
# 9986       16327.0         741.0
# 9987       44682.0           NaN
# 9988       21654.0         739.0
# 9989       11724.0         740.0
# 9990        3437.0         751.0
# 9991        2313.0         738.0
# 9992        5741.0         690.0
# 9993       27177.0         692.0
# 9994       18838.0         705.0
# 9995       15046.0         745.0
# 9996       32996.0           NaN
# 9997       36912.0         695.0
# 9998       13506.0         744.0
# 9999       23440.0        6820.0
#
# [10000 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
# index                           10000 non-null int64
# Home Ownership                  10000 non-null object
# Annual Income                   7930 non-null float64
# Years in current job            9543 non-null object
# Tax Liens                       10000 non-null object
# Number of Open Accounts         10000 non-null float64
# Years of Credit History         10000 non-null float64
# Maximum Open Credit             10000 non-null float64
# Number of Credit Problems       10000 non-null object
# Months since last delinquent    4561 non-null float64
# Bankruptcies                    9983 non-null float64
# Purpose                         10000 non-null object
# Term                            10000 non-null object
# Current Loan Amount             10000 non-null float64
# Current Credit Balance          10000 non-null float64
# Monthly Debt                    10000 non-null float64
# Credit Score                    7930 non-null float64
# dtypes: float64(10), int64(1), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Работа с категориальными переменными

# %% [markdown]
# ### Работа с years in current job

# %%
# df.loc[df['Years in current job']=='10+ years', 'Years in current job'] = 10
# df.loc[df['Years in current job']=='9 years', 'Years in current job'] = 9
# df.loc[df['Years in current job']=='8 years', 'Years in current job'] = 8
# df.loc[df['Years in current job']=='7 years', 'Years in current job'] = 7
# df.loc[df['Years in current job']=='6 years', 'Years in current job'] = 6
# df.loc[df['Years in current job']=='5 years', 'Years in current job'] = 5
# df.loc[df['Years in current job']=='4 years', 'Years in current job'] = 4
# df.loc[df['Years in current job']=='3 years', 'Years in current job'] = 3
# df.loc[df['Years in current job']=='2 years', 'Years in current job'] = 2
# df.loc[df['Years in current job']=='1 year', 'Years in current job'] = 1
# df.loc[df['Years in current job']=='< 1 year', 'Years in current job'] = 0
# df['Years in current job'] = df['Years in current job'].astype("float64")
# df.loc[df['Years in current job'].isnull(), 'Years in current job'] = df['Years in current job'].mean()

# %% [markdown]
# ## Устранение выбросов

# %% [markdown]
# ### Нет выбросов в 'Monthly Debt

# %%
sns.boxplot(df['Monthly Debt'])

# %%
sns.kdeplot(df['Monthly Debt'], shade=True)

# %% [markdown]
# ### Устраняем выбросы в Maximum Open Credit

# %%
sns.boxplot(x=df['Maximum Open Credit'])

# %%
# Надо поэкспериментировать с этим параметром

# %%
# ver1
df.loc[df['Maximum Open Credit']>0.2*1e9, ['Maximum Open Credit']] = df['Maximum Open Credit'].median()

# ver2
#df.loc[df['Maximum Open Credit']>1*1e7, ['Maximum Open Credit']] = df['Maximum Open Credit'].median()
#df.loc[df['Maximum Open Credit']<0, ['Maximum Open Credit']] = df['Maximum Open Credit'].median()

# %%
sns.boxplot(x=df['Maximum Open Credit'])

# %% [markdown]
# ### Устраняем выбросы в Current Loan Amount

# %%
# 10% значений ощибочны (9999999999). Заменим их NaN, чтобы в дальнейшем восстановить регрессией
df.loc[df['Current Loan Amount']>1e7, 'Current Loan Amount'].count()
# Out:
# 1167

# %%
sns.boxplot(x=df['Current Loan Amount'])

# %%
#new = df['Current Loan Amount'].median()

# %%
#df.loc[df['Current Loan Amount'] > 0.4*1e8, ['Current Loan Amount']] = new

# %%
df.loc[df['Current Loan Amount'] > 0.4*1e8, ['Current Loan Amount']] = np.NaN

# %%
sns.boxplot(x=df['Current Loan Amount'])

# %% [markdown]
# ### Устраняем выбросы в Credit Score

# %%
sns.boxplot(x=df['Credit Score'])

# %%
high_values = df.loc[df['Credit Score']>5000, ['Credit Score']]

# %%
high_values = high_values/10

# %%
df.loc[df['Credit Score']>5000, ['Credit Score']] = high_values

# %%
sns.boxplot(x=df['Credit Score'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
# index                           10000 non-null int64
# Home Ownership                  10000 non-null object
# Annual Income                   7930 non-null float64
# Years in current job            9543 non-null object
# Tax Liens                       10000 non-null object
# Number of Open Accounts         10000 non-null float64
# Years of Credit History         10000 non-null float64
# Maximum Open Credit             10000 non-null float64
# Number of Credit Problems       10000 non-null object
# Months since last delinquent    4561 non-null float64
# Bankruptcies                    9983 non-null float64
# Purpose                         10000 non-null object
# Term                            10000 non-null object
# Current Loan Amount             8833 non-null float64
# Current Credit Balance          10000 non-null float64
# Monthly Debt                    10000 non-null float64
# Credit Score                    7930 non-null float64
# dtypes: float64(10), int64(1), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Нормализация распределений

# %% [markdown]
# ### Нормализация Number of Open Accounts

# %%
sns.kdeplot(df['Number of Open Accounts'], shade=True)

# %%
xt, _ = stats.boxcox(df['Number of Open Accounts'])

# %%
df['Number of Open Accounts'] = xt

# %%
sns.kdeplot(df['Number of Open Accounts'], shade=True)

# %% [markdown]
# ### Нормализация Years of Credit History

# %%
sns.kdeplot(df['Years of Credit History'], shade=True)

# %%
xt, _ = stats.boxcox(df['Years of Credit History'])

# %%
df['Years of Credit History'] = xt

# %%
sns.kdeplot(df['Years of Credit History'], shade=True)

# %% [markdown]
# ### Нормализация Current Credit Balance (точнсть снизилась)

# %%
#sns.kdeplot(df['Current Credit Balance'], shade=True)

# %%
# Так точность снизилась
#df['Current Credit Balance'] = df['Current Credit Balance']**0.2

# %%
#df['Current Credit Balance'] = df['Current Credit Balance'] + 1

# %%
#xt, _ = stats.boxcox(df['Current Credit Balance'])

# %%
#df['Current Credit Balance'] = xt

# %%
#sns.kdeplot(df['Current Credit Balance'], shade=True)

# %% [markdown]
# ### Нормализация Monthly Debt

# %%
sns.kdeplot(df['Monthly Debt'], shade=True)

# %%
df['Monthly Debt'] = df['Monthly Debt'] + 1

# %%
xt, _ = stats.boxcox(df['Monthly Debt'])

# %%
df['Monthly Debt'] = xt

# %%
sns.kdeplot(df['Monthly Debt'], shade=True)

# %% [markdown]
# ## Устранение пропущенных значений

# %% [markdown]
# ### Устранение пропущенных значений Years in current job

# %%
df['Years in current job'] = df['Years in current job'].fillna(df['Years in current job'].mode()[0])

# %% [markdown]
# ### Удаляем Months since last delinquent, так как много пропущенных значений

# %%
df.drop(columns=['Months since last delinquent'], axis = 1, inplace = True)

# %% [markdown]
# ### Устранение пропущенных значений Bankruptcies

# %%
mode = (df['Bankruptcies'].mode())[0]
df.loc[df['Bankruptcies'].isnull(), ['Bankruptcies']] = mode

# %% [markdown]
# ### Стандартизация данных (здесь не работает, так как бокс кокс не будет работать) реализована ниже

# %%
NUM_FEATURE_NAMES = ['Annual Income', 'Number of Open Accounts', 'Years of Credit History',
                     'Maximum Open Credit',# 'Months since last delinquent',#'new',
                     'Bankruptcies', 'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt', 'Credit Score']

# %%
# scaler = StandardScaler()

# df_norm = df.copy()
# df_norm[NUM_FEATURE_NAMES] = scaler.fit_transform(df_norm[NUM_FEATURE_NAMES])

# df = df_norm.copy()

# %% [markdown]
# ### Устранение пропущенных значений Current Loan Amount через регрессию

# %%
sns.kdeplot(df['Current Loan Amount'], shade=True)
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
test = df.loc[df['Current Loan Amount'].isnull()].drop('Current Loan Amount', axis=1)
train = df.loc[df['Current Loan Amount'].notnull()]

# %%
cat_features = ['Home Ownership', 'Purpose', 'Term', 'Tax Liens', 'Number of Credit Problems', 'Years in current job']

# %%
sns.kdeplot(train['Current Loan Amount'], shade=True)

# %%
model = catb.CatBoostRegressor(n_estimators=500, max_depth=3,
                                       silent=True, random_state=21, cat_features = cat_features)

# %%
y = train['Current Loan Amount']
X = train.drop('Current Loan Amount', axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                    train_size=0.8, test_size=0.2, random_state=0)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_valid)

# %%
mae_2 = mean_absolute_error(y_valid, y_pred)

# %%
mae_2
# Out:
# 103764.42872966203

# %%
r_2 = r2_score(y_valid, y_pred)

# %%
r_2
# Out:
# 0.46586609219010167

# %%
model.fit(X, y)

# %%
result = model.predict(test)
test['Current Loan Amount'] = result
df.loc[df['Current Loan Amount'].isnull(), ['Current Loan Amount']] = test['Current Loan Amount']

# %%
important_features_top = show_feature_importances(X_train.columns, model.feature_importances_, get_top=11)

# %%
sns.kdeplot(df['Current Loan Amount'], shade=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
# index                        10000 non-null int64
# Home Ownership               10000 non-null object
# Annual Income                7930 non-null float64
# Years in current job         10000 non-null object
# Tax Liens                    10000 non-null object
# Number of Open Accounts      10000 non-null float64
# Years of Credit History      10000 non-null float64
# Maximum Open Credit          10000 non-null float64
# Number of Credit Problems    10000 non-null object
# Bankruptcies                 10000 non-null float64
# Purpose                      10000 non-null object
# Term                         10000 non-null object
# Current Loan Amount          10000 non-null float64
# Current Credit Balance       10000 non-null float64
# Monthly Debt                 10000 non-null float64
# Credit Score                 7930 non-null float64
# dtypes: float64(9), int64(1), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Устранение пропущенных значений Credit Score через регрессию

# %%
test = df.loc[df['Credit Score'].isnull()].drop('Credit Score', axis=1)
train = df.loc[df['Credit Score'].notnull()]

# %%
cat_features = ['Home Ownership', 'Purpose', 'Term', 'Tax Liens', 'Number of Credit Problems', 'Years in current job']

# %%
sns.kdeplot(train['Credit Score'], shade=True)

# %%
xt, _ = stats.boxcox(train['Credit Score'])

# %%
train['Credit Score'] = xt/1e40
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.kdeplot(train['Credit Score'], shade=True)

# %%
#model = catb.CatBoostRegressor(n_estimators=650, max_depth=3, #l2_leaf_reg = 0.01,
model = catb.CatBoostRegressor(n_estimators=400, max_depth=5,
                                       silent=True, random_state=21, cat_features = cat_features)

# %%
y = train['Credit Score']
X = train.drop('Credit Score', axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                    train_size=0.8, test_size=0.2, random_state=0)

# %%
# Обучаем на части данных, чтобы проверить точность на валидационной части
model.fit(X_train, y_train)
y_pred = model.predict(X_valid)

# %%
mae_2 = mean_absolute_error(y_valid, y_pred)

# %%
mae_2
# Out:
# 8709489.673250545

# %%
r_2 = r2_score(y_valid, y_pred)

# %%
r_2
# Out:
# 0.3813635691537557

# %%
# Обучаем на полном наборе данных, чтобы повысить точность
model.fit(X, y)

# %%
with open(MODEL_1_FILE_PATH, 'wb') as file:
    pickle.dump(model, file)

# %%
result = model.predict(test)
test['Credit Score'] = result
df.loc[df['Credit Score'].isnull(), ['Credit Score']] = test['Credit Score']
#df.loc[df['Credit Score'].isnull(), ['Credit Score']] = df['Credit Score'].median()

# %%
important_features_top = show_feature_importances(X_train.columns, model.feature_importances_, get_top=11)

# %% [markdown]
# ### Устранение пропущенных значений Annual Income через регрессию

# %%
df.loc[df['Annual Income'] > 0.5*1e7,['Annual Income']] = df['Annual Income'].median()

# %%
sns.boxplot(x=df['Annual Income'])

# %%
# Построим зависимость Annual Income от Monthly Debt, Current Credit Balance и Current Loan Amount
# Новый тестовый датафрейм для определения пропущенных значений Annual Income

test = df.loc[df['Annual Income'].isnull()].drop('Annual Income', axis=1)
# Новый тренировочный датафрейм для определения пропущенных значений Annual Income

train = df.loc[df['Annual Income'].notnull()]

# %%
cat_features = ['Home Ownership', 'Purpose', 'Term', 'Tax Liens', 'Number of Credit Problems', 'Years in current job']

# %%
sns.kdeplot(train['Annual Income'], shade=True)

# %%
xt, _ = stats.boxcox(train['Annual Income'])

# %%
train['Annual Income'] = xt
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.kdeplot(train['Annual Income'], shade=True)

# %%
#model = catb.CatBoostRegressor(n_estimators=500, max_depth=3,
model = catb.CatBoostRegressor(n_estimators=500, max_depth=5,
                                       silent=True, random_state=21, cat_features = cat_features)

# %%
y = train['Annual Income']
X = train.drop('Annual Income', axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                    train_size=0.8, test_size=0.2, random_state=0)

# %%
# Обучаем на части данных, чтобы проверить точность на валидационной части
model.fit(X_train, y_train)
y_pred = model.predict(X_valid)

# %%
mae_2 = mean_absolute_error(y_valid, y_pred)

# %%
mae_2
# Out:
# 0.6850385300121387

# %%
r_2 = r2_score(y_valid, y_pred)

# %%
r_2
# Out:
# 0.5233223939279001

# %%
# Обучаем на полном наборе данных, чтобы повысить точность
model.fit(X, y)

# %%
with open(MODEL_2_FILE_PATH, 'wb') as file:
    pickle.dump(model, file)

# %%
result = model.predict(test)
test['Annual Income'] = result
df.loc[df['Annual Income'].isnull(), ['Annual Income']] = test['Annual Income']
#df.loc[df['Annual Income'].isnull(), ['Annual Income']] = df['Annual Income'].median()

# %%
important_features_top = show_feature_importances(X_train.columns, model.feature_importances_, get_top=11)

# %% [markdown]
# #### Уменьшение числа признаков не привело к повышению точности

# %% [markdown]
# ## Разделение на train и test

# %%
df_train = df.iloc[0:7500,:].drop('index', axis=1)

# %%
df_train.tail()
# Out:
#      Home Ownership  Annual Income Years in current job   Tax Liens  \
# 7495           Rent   4.021920e+05             < 1 year  Less_equ_1
# 7496  Home Mortgage   1.533984e+06               1 year  Less_equ_1
# 7497           Rent   1.878910e+06              6 years  Less_equ_1
# 7498  Home Mortgage   2.466989e+01            10+ years  Less_equ_1
# 7499           Rent   2.223304e+01              4 years  Less_equ_1
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 7495                 1.259180                 2.457808             107866.0
# 7496                 3.085544                 4.061032             686312.0
# 7497                 3.411702                 4.354792            1778920.0
# 7498                 4.507975                 4.061032            1141250.0
# 7499                 2.705527                 2.590591             480832.0
#
#      Number of Credit Problems  Bankruptcies Purpose        Term  \
# 7495                Less_equ_3           0.0  Class2  Short Term
# 7496                Less_equ_3           0.0  Class2   Long Term
# 7497                Less_equ_3           0.0  Class2  Short Term
# 7498                Less_equ_3           0.0  Class2  Short Term
# 7499                Less_equ_3           0.0  Class2  Short Term
#
#       Current Loan Amount  Current Credit Balance  Monthly Debt  Credit Score
# 7495        129360.000000                 73492.0     48.288903  6.970000e+02
# 7496        444048.000000                456399.0    106.018208  7.410000e+02
# 7497        360969.734145                477812.0    104.982774  7.480000e+02
# 7498        615274.000000                476064.0    163.425334  1.054191e+07
# 7499         26928.000000                288192.0     92.117168  2.184704e+07

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 15 columns):
# Home Ownership               7500 non-null object
# Annual Income                7500 non-null float64
# Years in current job         7500 non-null object
# Tax Liens                    7500 non-null object
# Number of Open Accounts      7500 non-null float64
# Years of Credit History      7500 non-null float64
# Maximum Open Credit          7500 non-null float64
# Number of Credit Problems    7500 non-null object
# Bankruptcies                 7500 non-null float64
# Purpose                      7500 non-null object
# Term                         7500 non-null object
# Current Loan Amount          7500 non-null float64
# Current Credit Balance       7500 non-null float64
# Monthly Debt                 7500 non-null float64
# Credit Score                 7500 non-null float64
# dtypes: float64(9), object(6)
# memory usage: 879.0+ KB

# %%
df_test = df.iloc[7500:,:].drop('index', axis=1).reset_index().drop('index', axis=1)

# %%
df_test.tail()
# Out:
#      Home Ownership  Annual Income Years in current job   Tax Liens  \
# 2495  Home Mortgage   1.020053e+06            10+ years  Less_equ_1
# 2496  Home Mortgage   2.488101e+01              2 years  Less_equ_1
# 2497  Home Mortgage   1.171806e+06              2 years  Less_equ_1
# 2498           Rent   7.235200e+05            10+ years  Less_equ_1
# 2499           Rent   1.694439e+06            10+ years  Less_equ_1
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 2495                 3.698962                 4.203556             559152.0
# 2496                 3.831057                 3.407532            1737780.0
# 2497                 6.426166                 3.008629            1706430.0
# 2498                 3.698962                 4.187692             945780.0
# 2499                 3.411702                 3.521356            1199748.0
#
#      Number of Credit Problems  Bankruptcies Purpose        Term  \
# 2495                Less_equ_3           1.0  Class2  Short Term
# 2496                Less_equ_3           0.0  Class2  Short Term
# 2497                Less_equ_3           0.0  Class2  Short Term
# 2498                Less_equ_3           0.0  Class2  Short Term
# 2499                Less_equ_3           0.0  Class2   Long Term
#
#       Current Loan Amount  Current Credit Balance  Monthly Debt  Credit Score
# 2495         224786.70146                162735.0    113.297672  7.450000e+02
# 2496         468512.00000               1439269.0    155.824593  1.140552e+07
# 2497         430496.00000                676438.0    163.057905  6.950000e+02
# 2498         257774.00000                391248.0    108.422671  7.440000e+02
# 2499         763004.00000                559531.0    135.663669  6.820000e+02

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
# Home Ownership               2500 non-null object
# Annual Income                2500 non-null float64
# Years in current job         2500 non-null object
# Tax Liens                    2500 non-null object
# Number of Open Accounts      2500 non-null float64
# Years of Credit History      2500 non-null float64
# Maximum Open Credit          2500 non-null float64
# Number of Credit Problems    2500 non-null object
# Bankruptcies                 2500 non-null float64
# Purpose                      2500 non-null object
# Term                         2500 non-null object
# Current Loan Amount          2500 non-null float64
# Current Credit Balance       2500 non-null float64
# Monthly Debt                 2500 non-null float64
# Credit Score                 2500 non-null float64
# dtypes: float64(9), object(6)
# memory usage: 293.0+ KB

# %% [markdown]
# ## Разделение признаков

# %%
NUM_FEATURE_NAMES = ['Annual Income', 'Number of Open Accounts', 'Years of Credit History',
                     'Maximum Open Credit',# 'Months since last delinquent',#'new',
                     'Bankruptcies', 'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt', 'Credit Score']

CAT_FEATURE_NAMES = ['Home Ownership', 'Purpose', 'Term', 'Tax Liens', 'Number of Credit Problems', 'Years in current job']

SELECTED_FEATURE_NAMES = NUM_FEATURE_NAMES + CAT_FEATURE_NAMES
TARGET_NAME = 'Credit Default'

# %%
X = df_train[SELECTED_FEATURE_NAMES]
#y = df_train[TARGET_NAME]

# %% [markdown]
# ## Стандартизация данных (не дала прироста точности)

# %%
# scaler = StandardScaler()

# df_norm = df_train.copy()
# df_norm[NUM_FEATURE_NAMES] = scaler.fit_transform(df_norm[NUM_FEATURE_NAMES])

# df_train = df_norm.copy()

# %%
X = df_train[SELECTED_FEATURE_NAMES]
#y = df_train[TARGET_NAME]

# %% [markdown]
# ## Разбиение на train и valid

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y_df, shuffle=True, test_size=0.30, random_state=12)

# %%
#X_train, X_valid, y_train, y_valid = train_test_split(X_resampled, y_resampled, shuffle=True, test_size=0.30, random_state=21)

# %% [markdown]
# ## Балансировка целевой переменной через библиотеку

# %% [markdown]
# Чтобы наиболее правильно оценить работу алгоритма, производить балансировку нужно после разбиения на train и valid.

# %% [markdown]
# Если произвести балансировку до разбиения, то дубликаты попадут и в train и в valid. И точность итогового алгоритма будет завышена.

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=21)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

from collections import Counter
print(sorted(Counter(y_resampled).items()))
X_train = X_resampled
y_train = y_resampled
# Out:
# [(0, 3759), (1, 3759)]

# %%
# df_for_balancing = pd.concat([X_train, y_train], axis=1)
# df_balanced = balance_df_by_target(df_for_balancing, TARGET_NAME)
    
# df_balanced[TARGET_NAME].value_counts()

# %%
# X_train = df_balanced.drop(columns=TARGET_NAME)
# y_train = df_balanced[TARGET_NAME]

# %% [markdown]
# ## Построение модели catBoost

# %%
model_catb = catb.CatBoostClassifier(n_estimators=550, max_depth=4, l2_leaf_reg=10,
                                      silent=True, random_state=21, cat_features = CAT_FEATURE_NAMES, 
                                     class_weights=[1, 0.7])
model_catb.fit(X_train, y_train)

y_train_pred = model_catb.predict(X_train)
y_valid_pred = model_catb.predict(X_valid)

get_classification_report(y_train, y_train_pred, y_valid, y_valid_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.87      0.75      3759
#            1       0.81      0.54      0.64      3759
#
#     accuracy                           0.70      7518
#    macro avg       0.73      0.70      0.69      7518
# weighted avg       0.73      0.70      0.69      7518
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.80      1628
#            1       0.46      0.37      0.41       622
#
#     accuracy                           0.71      2250
#    macro avg       0.62      0.60      0.61      2250
# weighted avg       0.69      0.71      0.70      2250
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1360  268
# 1                393  229

# %% [markdown]
# ## Отбор признаков

# %%
important_features_top = show_feature_importances(X_train.columns, model_catb.feature_importances_, get_top=15)

# %%
important_features_top
# Out:
# ['Annual Income',
#  'Credit Score',
#  'Maximum Open Credit',
#  'Current Loan Amount',
#  'Years of Credit History',
#  'Current Credit Balance',
#  'Monthly Debt',
#  'Term',
#  'Number of Open Accounts',
#  'Home Ownership',
#  'Years in current job',
#  'Purpose',
#  'Bankruptcies',
#  'Tax Liens',
#  'Number of Credit Problems']

# %%
cat_features = list(set(CAT_FEATURE_NAMES) & set(important_features_top))

# %%
cat_features
# Out:
# ['Home Ownership',
#  'Years in current job',
#  'Purpose',
#  'Number of Credit Problems',
#  'Term',
#  'Tax Liens']

# %%
model_catb = catb.CatBoostClassifier(n_estimators=500, max_depth=3,
                                        # это были лучшие параметры без балансировки целевой переменной
                                      #silent=True, random_state=21, cat_features = cat_features, class_weights=[1, 2.56])
                                     # это были лучшие параметры с балансировкой целевой переменной
                                     silent=True, random_state=21, cat_features = cat_features, class_weights=[1, 0.7])
                                     #silent=True, random_state=21, cat_features = cat_features, class_weights=[1, 1.27])
model_catb.fit(X_train[important_features_top], y_train)

y_train_pred = model_catb.predict(X_train[important_features_top])
y_valid_pred = model_catb.predict(X_valid[important_features_top])
y_test_pred_probs = model_catb.predict_proba(X_valid[important_features_top])

get_classification_report(y_train, y_train_pred, y_valid, y_valid_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73      3759
#            1       0.79      0.51      0.62      3759
#
#     accuracy                           0.69      7518
#    macro avg       0.71      0.69      0.68      7518
# weighted avg       0.71      0.69      0.68      7518
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.80      1628
#            1       0.44      0.36      0.39       622
#
#     accuracy                           0.70      2250
#    macro avg       0.60      0.59      0.60      2250
# weighted avg       0.68      0.70      0.69      2250
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1341  287
# 1                399  223

# %%
y_p = np.array(y_test_pred_probs[:,1]>0.5).astype('int') #>0.55

get_classification_report(y_train, y_train_pred, y_valid, y_p)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73      3759
#            1       0.79      0.51      0.62      3759
#
#     accuracy                           0.69      7518
#    macro avg       0.71      0.69      0.68      7518
# weighted avg       0.71      0.69      0.68      7518
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.80      1628
#            1       0.44      0.36      0.39       622
#
#     accuracy                           0.70      2250
#    macro avg       0.60      0.59      0.60      2250
# weighted avg       0.68      0.70      0.69      2250
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1341  287
# 1                399  223

# %% [markdown]
# ## Получение результата

# %% [markdown]
# ### Балансировка целевой переменной

# %%
ros = RandomOverSampler(random_state=21)
X_resampled, y_resampled = ros.fit_resample(X, y_df)

# %%
print(sorted(Counter(y_resampled).items()))
X = X_resampled
y_df = y_resampled
# Out:
# [(0, 5387), (1, 5387)]

# %% [markdown]
# ### Обучение итоговой модели и сохранеие результата

# %%
model_catb.fit(X[important_features_top], y_df)

# %%
with open(MODEL_3_FILE_PATH, 'wb') as file:
    pickle.dump(model_catb, file)

# %%
df_test['Credit Default'] = model_catb.predict(df_test[important_features_top])

# %%
df_test.loc[:, ['Credit Default']].head()
# Out:
#    Credit Default
# 0               0
# 1               1
# 2               0
# 3               0
# 4               0

# %%
# Сохранение результата, полученного на тестовой выборке
df_test.loc[:, ['Credit Default']].to_csv('DFedorov_predictions.csv', index=None)

# %%
# Получение результата на тренировочной выборке для мониторинга точности
y_train_pred = model_catb.predict(X[important_features_top])

# %%
print('TRAIN\n\n' + classification_report(y_df, y_train_pred))
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.86      0.72      5387
#            1       0.77      0.48      0.59      5387
#
#     accuracy                           0.67     10774
#    macro avg       0.70      0.67      0.65     10774
# weighted avg       0.70      0.67      0.65     10774
